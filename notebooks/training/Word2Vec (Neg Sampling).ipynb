# %% [markdown]
# # Word2Vec (Negative Sampling)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from string import punctuation
import time

# %%
import nltk
from nltk.corpus import brown
from nltk.corpus import stopwords
from collections import Counter
import matplotlib
nltk.download('stopwords')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\swara\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\swara\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %% [markdown]
# ## 1. Load data

# %%
corpus = brown.sents()

# %%
stop_words = set(stopwords.words('english'))
corpus = [[word for word in sent if word.lower() not in stop_words] for sent in corpus]

# Remove punctuation from corpus
corpus = [[word for word in sent if word not in punctuation] for sent in corpus]

# Remove empty sentences
corpus = [sent for sent in corpus if len(sent) > 0]

# Remove sentences with less than 5 words
corpus = [sent for sent in corpus if len(sent) >= 5]

# Remove sentences with more than 20 words
corpus = [sent for sent in corpus if len(sent) <= 20]

# Remove rare words
word_freq = Counter([word for sent in corpus for word in sent])
corpus = [[word for word in sent if word_freq[word] > 5] for sent in corpus]

# %%
#2. numeralization
#find unique words
flatten = lambda l: [item for sublist in l for item in sublist]
#assign unique integer
vocabs = list(set(flatten(corpus))) #all the words we have in the system - <UNK>

# %%
#create handy mapping between integer and word
word2index = {v:idx for idx, v in enumerate(vocabs)}
word2index['dog']
# Out:
# 2319

# %%
vocabs.append('<UNK>')
word2index['<UNK>'] = len(vocabs)

# %%
index2word = {v:k for k, v in word2index.items()}
index2word[5]
# Out:
# 'Club'

# %% [markdown]
# ## 2. Prepare train data

# %%
#create pairs of center word, and outside word

def random_batch(batch_size, corpus, window_size=2):

    skipgrams = []

    #loop each corpus
    for doc in corpus:
        #look from the 2nd word until second last word
        for i in range(window_size, len(doc) - window_size):
            #center word
            center = word2index[doc[i]]
            #outside words = rest of the words
            outside_start =  i - window_size
            outside_end =  i + window_size + 1

            for j in range(outside_start, outside_end):
                if i != j:  # Skip the center word
                    outside = word2index[doc[j]]
                    skipgrams.append([center, outside])
                
    random_index = np.random.choice(range(len(skipgrams)), batch_size, replace=False)
    
    inputs, labels = [], []
    for index in random_index:
        inputs.append([skipgrams[index][0]])
        labels.append([skipgrams[index][1]])
        
    return np.array(inputs), np.array(labels)
            
x, y = random_batch(2, corpus)

# %%
x.shape  #batch_size, 1
# Out:
# (2, 1)

# %%
x
# Out:
# array([[7878],
#        [5447]])

# %%
y.shape  #batch_size 1
# Out:
# (2, 1)

# %% [markdown]
# ## 3. Negative Sampling
#
# ### Unigram distribution
#
# $$P(w)=U(w)^{3/4}/Z$$

# %%
z = 0.001

# %%
#count
from collections import Counter

word_count = Counter(flatten(corpus))
word_count

#get the total number of words
num_total_words = sum([c for w, c in word_count.items()])
num_total_words
# Out:
# 356098

# %%
vocabs
# Out:
# ['assumptions',
#  'impossible',
#  'Boys',
#  'worn',
#  'intellectual',
#  'Club',
#  'Market',
#  'French',
#  'rope',
#  'however',
#  'Turkish',
#  'stared',
#  'sponsored',
#  'slipped',
#  'proof',
#  'age',
#  'Dr.',
#  'Colorado',
#  'emotions',
#  'earlier',
#  'Nelson',
#  'eloquent',
#  'playing',
#  'register',
#  'concepts',
#  'Monroe',
#  'compiled',
#  'One',
#  'tremendous',
#  'direction',
#  'Publications',
#  'ordinary',
#  'C',
#  'Chapel',
#  'angle',
#  'theology',
#  'contributions',
#  'era',
#  'Academy',
#  'vertical',
#  'skin',
#  'waving',
#  'singers',
#  'blunt',
#  'live',
#  'react',
#  'Achievement',
#  'adjust',
#  'lump',
#  'Youth',
#  'theoretical',
#  'springs',
#  'selfish',
#  'decides',
#  'watercolor',
#  'remind',
#  'Turning',
#  'slice',
#  'lead',
#  'travel',
#  'sake',
#  'Yes',
#  'Joseph',
#  'remark',
#  'leaders',
#  'surrendered',
#  'Dumont',
#  'supplied',
#  'approaching',
#  'honors',
#  'camera',
#  'university',
#  'acted',
#  'element',
#  'neurotic',
#  'match',
#  'FBI',
#  'filtered',
#  'consistent',
#  'phenomena',
#  'brighter',
#  'name',
#  'H',
#  'Gen.',
#  "Can't",
#  'continue',
#  'farmers',
#  'conjunction',
#  'shut',
#  'Following',
#  'Mass',
#  'northeast',
#  'multiplicity',
#  'swelling',
#  'occasion',
#  'map',
#  'aborigines',
#  'Tony',
#  'biological',
#  'circle',
#  'Lucy',
#  'Unless',
#  'contempt',
#  'Copernican',
#  'bride',
#  'housing',
#  'returns',
#  'prices',
#  'Week',
#  'Whenever',
#  'sentence',
#  'walking',
#  'paths',
#  'conventions',
#  'adolescent',
#  'dashed',
#  '1832',
#  'aircraft',
#  'kingdom',
#  'Guard',
#  'communicative',
#  'grand',
#  'privileges',
#  'looks',
#  'sites',
#  'ballet',
#  'prominently',
#  'suitcase',
#  'emptied',
#  'evil',
#  'parent',
#  'text',
#  'heater',
#  'buffer',
#  'Bake',
#  'precisely',
#  'choices',
#  'indicators',
#  'warming',
#  'depending',
#  'stretched',
#  'elimination',
#  'Lauro',
#  "1/4''",
#  'Soviet',
#  'billion',
#  'completely',
#  'muzzle',
#  'enthusiasm',
#  'mounted',
#  'Drexel',
#  'service',
#  '150',
#  'Jersey',
#  'growth',
#  'Kayabashi',
#  'Krim',
#  'ironic',
#  'couples',
#  'chin',
#  'oils',
#  'convenience',
#  'sensual',
#  'hazards',
#  'illusion',
#  'departing',
#  'scholarships',
#  'momentum',
#  'pause',
#  'attacks',
#  'irregular',
#  'actuality',
#  'accessories',
#  'annual',
#  'gloves',
#  'Eastern',
#  'director',
#  'illness',
#  'indirect',
#  'ridge',
#  'Lord',
#  'personnel',
#  'Hub',
#  'sheer',
#  'Anniston',
#  'brains',
#  'correspondent',
#  'silence',
#  'depth',
#  'drastically',
#  'composers',
#  'Side',
#  'innocence',
#  'apparent',
#  'unconsciously',
#  'Ramsey',
#  'literally',
#  'achievements',
#  'piled',
#  'Suddenly',
#  'Johnston',
#  'vector',
#  'doll',
#  'hauled',
#  'judge',
#  'Hoag',
#  'almost',
#  'forty-four',
#  '7',
#  'Marshal',
#  'masses',
#  'spy',
#  'therapist',
#  'positivist',
#  'proud',
#  'predict',
#  'fluids',
#  'moved',
#  'Beverly',
#  'Andy',
#  'collar',
#  'elegance',
#  'messages',
#  'sixteen',
#  'ceiling',
#  'convention',
#  'suffering',
#  'misfortune',
#  'Shakespeare',
#  'breath',
#  'pit',
#  'content',
#  'reverse',
#  'Queen',
#  'easier',
#  'falling',
#  'implied',
#  'contacts',
#  'cultural',
#  'texture',
#  'Anglo-Saxon',
#  'swear',
#  'enthusiastic',
#  'Bridge',
#  'expressions',
#  'uneasy',
#  'given',
#  'word',
#  'wool',
#  'plowing',
#  'performances',
#  'dusty',
#  'dressing',
#  'bolt',
#  'musician',
#  'tongue',
#  'colorful',
#  'boats',
#  'bruised',
#  'People',
#  "we'll",
#  'disease',
#  'cattle',
#  'substances',
#  'violently',
#  'secant',
#  'conclusions',
#  'Tommy',
#  'X',
#  'Fourth',
#  'disposed',
#  'yarns',
#  'popularity',
#  'anyone',
#  'developing',
#  'camp',
#  'Accordingly',
#  'shelters',
#  'salesmen',
#  'mayor',
#  'leaving',
#  'Using',
#  'excellence',
#  'tobacco',
#  'deliberate',
#  'v.',
#  'chaos',
#  'relief',
#  'highest',
#  'dozen',
#  'compensation',
#  'master',
#  'mechanism',
#  "bull's-eyes",
#  'official',
#  'volunteer',
#  'tracing',
#  'Ryan',
#  "Hudson's",
#  'collapsed',
#  'nursing',
#  'objections',
#  'deemed',
#  'joint',
#  'costume',
#  'message',
#  'joys',
#  'hairs',
#  'credited',
#  'average',
#  'forecasting',
#  'hats',
#  'sweep',
#  'issues',
#  'comfort',
#  'comments',
#  'claiming',
#  'applause',
#  'undertaken',
#  'Perry',
#  'Mother',
#  'community',
#  'cost',
#  'deputy',
#  'verdict',
#  'properly',
#  'anecdote',
#  'banished',
#  'conjugates',
#  'representative',
#  'access',
#  'acquisition',
#  'Hank',
#  'troubled',
#  'completion',
#  'warmly',
#  'job',
#  'connected',
#  'rated',
#  'changes',
#  'bothered',
#  'skywave',
#  'Horn',
#  'alive',
#  'Paris',
#  'Perhaps',
#  'park',
#  'weakness',
#  'metaphysical',
#  'sloping',
#  "She'll",
#  'ladder',
#  'Holy',
#  'catastrophe',
#  'Kate',
#  'locks',
#  'marijuana',
#  'seat',
#  'recommendation',
#  'McCormick',
#  'everyone',
#  'capture',
#  'forecast',
#  'goods',
#  'disguised',
#  'occupation',
#  'planned',
#  'shoved',
#  'security',
#  'observer',
#  'starvation',
#  'reception',
#  'tone',
#  'embodiment',
#  'one',
#  'outlook',
#  'murders',
#  'Word',
#  '200',
#  'drifted',
#  'jerked',
#  'restrictions',
#  'decoration',
#  'Cologne',
#  'Tessie',
#  'Harry',
#  'ministers',
#  'R.',
#  'consecutive',
#  'Testament',
#  'spare',
#  'Yankee',
#  'quantities',
#  'fascinated',
#  "Christ's",
#  'burned',
#  'communism',
#  'denoted',
#  'spectators',
#  'peace',
#  'Cotton',
#  'body',
#  'museum',
#  'caliber',
#  'religion',
#  'turnpikes',
#  'London',
#  'contented',
#  'cited',
#  'worried',
#  'ninety',
#  'distributed',
#  'Jews',
#  'dice',
#  'straightforward',
#  'summers',
#  'diagram',
#  'longer',
#  'dictionary',
#  'schoolhouse',
#  'lonely',
#  'unpopular',
#  'Additional',
#  'telephone',
#  'draft',
#  'flag',
#  'absence',
#  'minimum',
#  'swayed',
#  'application',
#  'Spencer',
#  'steadily',
#  'Amen',
#  'newcomer',
#  'productivity',
#  'Son',
#  'wished',
#  'advise',
#  'butyrate',
#  'Mrs.',
#  '32',
#  'frustration',
#  'sharply',
#  'price',
#  'graceful',
#  'Nick',
#  'ill',
#  'bin',
#  'Alec',
#  'twentieth',
#  'vines',
#  'motif',
#  'murdered',
#  'Carla',
#  'bacterial',
#  'characters',
#  'natives',
#  'line',
#  'cutters',
#  'phony',
#  'development',
#  'courtesy',
#  'specific',
#  'share',
#  'perform',
#  'ultrasonic',
#  'complement',
#  'UN',
#  'virtue',
#  'dazzling',
#  'Nicolas',
#  'dining',
#  'plow',
#  'refuse',
#  'dealing',
#  'thing',
#  '1/2',
#  'slower',
#  'Prince',
#  'vegetables',
#  'Rogers',
#  'magazines',
#  'withholding',
#  'Stuart',
#  'instrumental',
#  'juvenile',
#  'know',
#  'mercury',
#  'reign',
#  'receives',
#  'inquired',
#  'subject',
#  'teeth',
#  'mood',
#  'eleven',
#  'violation',
#  'nurse',
#  'mixed',
#  'creek',
#  'wave',
#  'basement',
#  'Hengesbach',
#  'packaging',
#  'boast',
#  'Buck',
#  'lengths',
#  'emotion',
#  'Stevie',
#  'Steichen',
#  'mean',
#  "they'd",
#  'preventing',
#  'decency',
#  'adult',
#  'taken',
#  'childhood',
#  'construct',
#  'exciting',
#  'border',
#  'makes',
#  'leveling',
#  'filing',
#  'involving',
#  'pretending',
#  'moods',
#  'infrared',
#  'Miller',
#  'meant',
#  'belly',
#  'swinging',
#  'Figure',
#  'cafe',
#  'parade',
#  'tables',
#  'naked',
#  'corporate',
#  'defensive',
#  'fame',
#  'adds',
#  'feared',
#  'pleased',
#  '1953',
#  'vitamins',
#  'associations',
#  'eagerly',
#  'exploration',
#  'Styka',
#  'absorbed',
#  'ahead',
#  'stake',
#  'existence',
#  'conferences',
#  'maximization',
#  '1949',
#  'wheeled',
#  'sweet',
#  'bounced',
#  'noting',
#  'brightness',
#  'superiority',
#  'secretary',
#  'glad',
#  'eyed',
#  'emphasis',
#  'attended',
#  'tours',
#  'Indonesia',
#  'sampling',
#  'Spirit',
#  'conservative',
#  'Jenkins',
#  'indicates',
#  'earliest',
#  'lacks',
#  'fond',
#  'collapse',
#  'bottle',
#  'getting',
#  'covers',
#  'York',
#  'Atlantic',
#  'armed',
#  'drainage',
#  'following',
#  'numbered',
#  'beans',
#  'tax',
#  'Angels',
#  '1940',
#  'branch',
#  'departure',
#  'denying',
#  'Funeral',
#  'summer',
#  'fix',
#  'mailed',
#  'noble',
#  'informal',
#  'sailors',
#  'broad',
#  'exhaust',
#  'quietly',
#  'territorial',
#  'distal',
#  'part',
#  'sterile',
#  'technical',
#  'Benington',
#  'Rayburn',
#  'Mass.',
#  'offers',
#  'Joyce',
#  'voting',
#  'gun',
#  'gained',
#  'departments',
#  'collectors',
#  'Last',
#  'boots',
#  'supporters',
#  'projections',
#  'major',
#  'detectives',
#  'prevents',
#  'luck',
#  'antibody',
#  'pending',
#  'analogy',
#  'professional',
#  'reproduce',
#  'hastily',
#  'Duke',
#  'Gloucester',
#  'humming',
#  'World',
#  'aboard',
#  'revolver',
#  'use',
#  'designated',
#  'Library',
#  'hut',
#  'Council',
#  'butter',
#  'Bourbons',
#  'classic',
#  'Like',
#  'extend',
#  'Love',
#  'ambition',
#  'silk',
#  'pro-Western',
#  'slavery',
#  'transparent',
#  'Y.',
#  'contrasts',
#  'two-thirds',
#  'bore',
#  'tools',
#  'drawing',
#  'speeches',
#  'domination',
#  'Brenner',
#  'outfit',
#  'congruence',
#  'practices',
#  'valued',
#  'minutes',
#  'alienation',
#  'entire',
#  'halted',
#  'gardens',
#  'emotional',
#  'glorious',
#  'orderly',
#  'board',
#  'largest',
#  'much',
#  'associated',
#  'Jackson',
#  'arms',
#  'Lilly',
#  'fly',
#  'hiding',
#  'realtors',
#  'surgeon',
#  'competing',
#  'restrict',
#  'producing',
#  'admiration',
#  'guards',
#  'occurs',
#  'full',
#  'joy',
#  'casually',
#  'furnishings',
#  'partisan',
#  'plot',
#  'wit',
#  'internal',
#  'progress',
#  'vicinity',
#  'neutral',
#  'running',
#  'computed',
#  '2:37',
#  'obligation',
#  'amplifier',
#  'ideal',
#  'supported',
#  'diameter',
#  'Barco',
#  'devised',
#  'sky',
#  'Development',
#  'bones',
#  'terror',
#  'millions',
#  'stranded',
#  'instructions',
#  'vapor',
#  'chapel',
#  'Warsaw',
#  'assuring',
#  'edges',
#  'Labor',
#  'magnetic',
#  'Japanese',
#  'reform',
#  'ordinarily',
#  'neck',
#  'liberal',
#  'Production',
#  'smoothly',
#  'compromise',
#  'flew',
#  'California',
#  'Tilghman',
#  'Board',
#  'even',
#  'bring',
#  'wholly',
#  'advised',
#  'although',
#  'Washington',
#  'heartily',
#  'ponds',
#  'tank',
#  'glasses',
#  'elevated',
#  'worship',
#  'stability',
#  'initially',
#  'shy',
#  'elder',
#  'peril',
#  'sovereignty',
#  'wounded',
#  'anniversary',
#  'conscious',
#  'mock',
#  'detergent',
#  'yelled',
#  'impose',
#  'Wally',
#  'love',
#  'incentive',
#  'utility',
#  'broken',
#  'finest',
#  'evenings',
#  'cats',
#  'drum',
#  'referring',
#  'Laura',
#  'mob',
#  'graph',
#  'visited',
#  'Hoot',
#  'Alexander',
#  'Virgin',
#  'Considering',
#  'discussions',
#  'routes',
#  'monkey',
#  'landed',
#  'metallic',
#  'drunken',
#  'led',
#  'poems',
#  'immediately',
#  'cosmetics',
#  'arrangements',
#  'slaughter',
#  'might',
#  'smashed',
#  'exert',
#  'ultimately',
#  'profit',
#  'respiratory',
#  'beef',
#  'readings',
#  'estimate',
#  'individualism',
#  'wagons',
#  'Hero',
#  'manifold',
#  'soiled',
#  'Gilborn',
#  'figured',
#  'secret',
#  'circles',
#  'farming',
#  'homer',
#  'Much',
#  'Holmes',
#  'prosperity',
#  'portions',
#  'glancing',
#  'pays',
#  'minute',
#  'immense',
#  'trials',
#  'clubs',
#  'compost',
#  'grammatical',
#  'Tom',
#  'royal',
#  'mice',
#  'Dick',
#  'divorce',
#  "We're",
#  'marriages',
#  'satisfaction',
#  'well-being',
#  'deeply',
#  'coach',
#  'sticking',
#  'Exchange',
#  'horse',
#  'incredibly',
#  'low',
#  'give',
#  'lagoon',
#  'hardly',
#  'operation',
#  'mail',
#  'adjoining',
#  'supply',
#  'notable',
#  'leaf',
#  'chill',
#  'masters',
#  "President's",
#  'insisted',
#  'injuries',
#  'anode',
#  'size',
#  'worse',
#  'true',
#  'virus',
#  'softly',
#  'grip',
#  'extra',
#  'directing',
#  'shrill',
#  'pushing',
#  'wife',
#  'writers',
#  'ethnic',
#  'gentle',
#  "Barco's",
#  'keeps',
#  'servant',
#  'expand',
#  'U',
#  'volumes',
#  'item',
#  'granting',
#  'inspired',
#  'Show',
#  'Aristotle',
#  'daughters',
#  'Hawaii',
#  'formulations',
#  'founded',
#  'wire',
#  'entering',
#  'accident',
#  'determination',
#  'pockets',
#  'Stanley',
#  'proportional',
#  'chain',
#  'balanced',
#  'odors',
#  'Republicans',
#  'reaches',
#  'bags',
#  'toast',
#  'gum',
#  'whispered',
#  'Presidential',
#  'Old',
#  '8,000',
#  'probable',
#  'fleeing',
#  'stomach',
#  'bottles',
#  'contrast',
#  'pear',
#  'religions',
#  'notify',
#  'beer',
#  'insist',
#  'reservoir',
#  'destroying',
#  'accurately',
#  'hardship',
#  'upon',
#  'done',
#  'Completion',
#  'forty',
#  'anaconda',
#  'Papa-san',
#  'Midwest',
#  'child',
#  'perceptions',
#  'youth',
#  'measurements',
#  'hard',
#  'cease',
#  'thirteen',
#  'supplying',
#  'month',
#  'send',
#  'regular',
#  'stillness',
#  'Staff',
#  'traces',
#  'inherited',
#  'retention',
#  'Langford',
#  "Welch's",
#  'intonation',
#  'iodide',
#  'Diana',
#  'polarization',
#  'guilt',
#  'scrap',
#  '0.5',
#  'proceedings',
#  'titled',
#  "He'd",
#  'Legislature',
#  'vivid',
#  'interests',
#  'wondering',
#  'hypothalamic',
#  'generators',
#  'brought',
#  'Ruanda-Urundi',
#  'invested',
#  'Powell',
#  "an'",
#  'purely',
#  'shed',
#  'studio',
#  'sources',
#  'visit',
#  "Miller's",
#  'flu',
#  "woman's",
#  'Hitler',
#  "patient's",
#  'scheduled',
#  'wanting',
#  'usual',
#  'expressing',
#  'welcome',
#  'Glendora',
#  'aesthetic',
#  'Sergeant',
#  'natural',
#  'frowned',
#  'assessed',
#  'darkened',
#  'spreading',
#  'Burton',
#  'hopes',
#  'animal',
#  'Would',
#  'hillside',
#  'speaking',
#  'troop',
#  'Timothy',
#  'Piepsam',
#  'manifest',
#  'introduction',
#  'fired',
#  'studies',
#  ...]

# %% [markdown]
# $$P(w)=U(w)^{3/4}/Z$$

# %%
unigram_table = []

for v in vocabs:
    uw = word_count[v] / num_total_words
    uw_alpha = int((uw ** 0.75) / z)
    unigram_table.extend([v] * uw_alpha)
    
Counter(unigram_table)
# Out:
# Counter({'``': 45,
#          "''": 45,
#          'one': 22,
#          '--': 22,
#          'would': 20,
#          'said': 17,
#          'could': 14,
#          'time': 14,
#          'two': 12,
#          'may': 12,
#          'man': 11,
#          'like': 11,
#          'first': 11,
#          'new': 10,
#          'also': 10,
#          'must': 10,
#          'made': 10,
#          'Af': 10,
#          'back': 10,
#          'much': 9,
#          'even': 9,
#          'years': 9,
#          'way': 9,
#          'many': 9,
#          'get': 8,
#          'see': 8,
#          'make': 8,
#          'little': 8,
#          'Mr.': 8,
#          'work': 8,
#          'people': 8,
#          'good': 8,
#          'well': 8,
#          'still': 8,
#          'know': 7,
#          'might': 7,
#          'came': 7,
#          'long': 7,
#          'used': 7,
#          'us': 7,
#          'men': 7,
#          'world': 7,
#          'year': 7,
#          'last': 7,
#          'life': 7,
#          'never': 7,
#          'use': 6,
#          'take': 6,
#          'New': 6,
#          'place': 6,
#          'another': 6,
#          'found': 6,
#          'right': 6,
#          'come': 6,
#          'old': 6,
#          'around': 6,
#          'home': 6,
#          'thought': 6,
#          'without': 6,
#          'went': 6,
#          'day': 6,
#          'small': 6,
#          'say': 6,
#          'great': 6,
#          'American': 6,
#          'three': 6,
#          'go': 6,
#          'state': 6,
#          'however': 5,
#          'One': 5,
#          'almost': 5,
#          'Mrs.': 5,
#          'part': 5,
#          'upon': 5,
#          'eyes': 5,
#          'left': 5,
#          'got': 5,
#          'better': 5,
#          '1': 5,
#          'knew': 5,
#          'fact': 5,
#          'end': 5,
#          'side': 5,
#          'always': 5,
#          'called': 5,
#          'away': 5,
#          'enough': 5,
#          'far': 5,
#          'think': 5,
#          'told': 5,
#          'put': 5,
#          'number': 5,
#          'high': 5,
#          'system': 5,
#          'every': 5,
#          'school': 5,
#          'house': 5,
#          'hand': 5,
#          'find': 5,
#          'course': 5,
#          'night': 5,
#          'less': 5,
#          'water': 5,
#          'something': 5,
#          'took': 5,
#          'since': 5,
#          'head': 5,
#          'given': 4,
#          'thing': 4,
#          'give': 4,
#          'done': 4,
#          'often': 4,
#          'area': 4,
#          'let': 4,
#          'program': 4,
#          'seemed': 4,
#          'interest': 4,
#          'important': 4,
#          'experience': 4,
#          'big': 4,
#          'going': 4,
#          'next': 4,
#          'want': 4,
#          'power': 4,
#          'different': 4,
#          'help': 4,
#          'look': 4,
#          'things': 4,
#          'best': 4,
#          'light': 4,
#          'turned': 4,
#          'group': 4,
#          'young': 4,
#          'nothing': 4,
#          'looked': 4,
#          'sense': 4,
#          'began': 4,
#          'felt': 4,
#          'problem': 4,
#          'though': 4,
#          '2': 4,
#          'along': 4,
#          'among': 4,
#          'mind': 4,
#          'kind': 4,
#          'least': 4,
#          'ever': 4,
#          'second': 4,
#          'door': 4,
#          'toward': 4,
#          'certain': 4,
#          'set': 4,
#          'room': 4,
#          'whole': 4,
#          'asked': 4,
#          'social': 4,
#          'order': 4,
#          'members': 4,
#          'open': 4,
#          'point': 4,
#          'children': 4,
#          'business': 4,
#          'face': 4,
#          'matter': 4,
#          'United': 4,
#          'need': 4,
#          'possible': 4,
#          'form': 4,
#          'case': 4,
#          'John': 4,
#          'early': 4,
#          'feet': 4,
#          'later': 4,
#          'present': 4,
#          'country': 4,
#          'general': 4,
#          'large': 4,
#          'several': 4,
#          'per': 4,
#          'rather': 4,
#          'public': 4,
#          'States': 4,
#          'become': 4,
#          'saw': 4,
#          'within': 4,
#          'family': 4,
#          'days': 4,
#          'four': 4,
#          'age': 3,
#          'name': 3,
#          'service': 3,
#          'word': 3,
#          'community': 3,
#          'cost': 3,
#          'job': 3,
#          'body': 3,
#          'line': 3,
#          'development': 3,
#          'taken': 3,
#          'York': 3,
#          'major': 3,
#          'full': 3,
#          'love': 3,
#          'wife': 3,
#          'child': 3,
#          'brought': 3,
#          'means': 3,
#          'reason': 3,
#          'week': 3,
#          'office': 3,
#          'air': 3,
#          'across': 3,
#          'seen': 3,
#          'together': 3,
#          'necessary': 3,
#          'anything': 3,
#          'level': 3,
#          'areas': 3,
#          'front': 3,
#          'change': 3,
#          'result': 3,
#          'living': 3,
#          'real': 3,
#          'church': 3,
#          'surface': 3,
#          'clear': 3,
#          'making': 3,
#          'study': 3,
#          'plan': 3,
#          'town': 3,
#          'available': 3,
#          'policy': 3,
#          'feel': 3,
#          'stood': 3,
#          'cannot': 3,
#          'heard': 3,
#          'future': 3,
#          'example': 3,
#          'woman': 3,
#          'provide': 3,
#          'five': 3,
#          'half': 3,
#          'whether': 3,
#          'girl': 3,
#          'really': 3,
#          'wanted': 3,
#          'Even': 3,
#          'law': 3,
#          'death': 3,
#          'close': 3,
#          'field': 3,
#          'yet': 3,
#          'turn': 3,
#          'started': 3,
#          'play': 3,
#          'boy': 3,
#          'outside': 3,
#          'today': 3,
#          'others': 3,
#          'city': 3,
#          'words': 3,
#          'action': 3,
#          'human': 3,
#          'past': 3,
#          'God': 3,
#          'history': 3,
#          'show': 3,
#          'Miss': 3,
#          'national': 3,
#          'seem': 3,
#          'war': 3,
#          'effect': 3,
#          'top': 3,
#          'moment': 3,
#          'either': 3,
#          'believe': 3,
#          'white': 3,
#          'State': 3,
#          'problems': 3,
#          'probably': 3,
#          'gave': 3,
#          'money': 3,
#          'information': 3,
#          'able': 3,
#          "I'm": 3,
#          'quite': 3,
#          'already': 3,
#          'free': 3,
#          'sure': 3,
#          'evidence': 3,
#          'held': 3,
#          'car': 3,
#          'perhaps': 3,
#          'seems': 3,
#          'individual': 3,
#          'local': 3,
#          'short': 3,
#          'value': 3,
#          'question': 3,
#          'position': 3,
#          '3': 3,
#          'ago': 3,
#          'tell': 3,
#          'President': 3,
#          'government': 3,
#          'period': 3,
#          'known': 3,
#          'became': 3,
#          'political': 3,
#          'behind': 3,
#          'company': 3,
#          'times': 3,
#          'keep': 3,
#          'hands': 3,
#          'common': 3,
#          'run': 3,
#          'voice': 3,
#          'usually': 3,
#          'special': 3,
#          'whose': 3,
#          'control': 3,
#          'type': 3,
#          'needed': 3,
#          'French': 2,
#          'Dr.': 2,
#          'earlier': 2,
#          'direction': 2,
#          'live': 2,
#          'lead': 2,
#          'Soviet': 2,
#          'completely': 2,
#          'growth': 2,
#          'moved': 2,
#          'anyone': 2,
#          'average': 2,
#          'changes': 2,
#          'peace': 2,
#          'longer': 2,
#          'subject': 2,
#          'mean': 2,
#          'makes': 2,
#          'getting': 2,
#          'following': 2,
#          'tax': 2,
#          'summer': 2,
#          'technical': 2,
#          'minutes': 2,
#          'entire': 2,
#          'board': 2,
#          'bring': 2,
#          'although': 2,
#          'Washington': 2,
#          'led': 2,
#          'immediately': 2,
#          'horse': 2,
#          'low': 2,
#          'size': 2,
#          'true': 2,
#          'hard': 2,
#          'month': 2,
#          'visit': 2,
#          'natural': 2,
#          'kept': 2,
#          'easy': 2,
#          'basic': 2,
#          'cent': 2,
#          'U.S.': 2,
#          'groups': 2,
#          'responsibility': 2,
#          'due': 2,
#          'force': 2,
#          'street': 2,
#          'friends': 2,
#          'college': 2,
#          'concerned': 2,
#          'data': 2,
#          'Congress': 2,
#          "can't": 2,
#          'hear': 2,
#          'involved': 2,
#          'East': 2,
#          'direct': 2,
#          'higher': 2,
#          'paper': 2,
#          'music': 2,
#          'Federal': 2,
#          'clearly': 2,
#          'City': 2,
#          'similar': 2,
#          'read': 2,
#          'carried': 2,
#          'forms': 2,
#          'care': 2,
#          'costs': 2,
#          'therefore': 2,
#          'passed': 2,
#          'dead': 2,
#          'modern': 2,
#          'hot': 2,
#          'method': 2,
#          'difference': 2,
#          'president': 2,
#          'military': 2,
#          'However': 2,
#          'quality': 2,
#          'lost': 2,
#          'series': 2,
#          'applied': 2,
#          'using': 2,
#          'ran': 2,
#          'son': 2,
#          'North': 2,
#          'shall': 2,
#          'inside': 2,
#          'soon': 2,
#          'member': 2,
#          'final': 2,
#          'schools': 2,
#          'types': 2,
#          'story': 2,
#          'generally': 2,
#          'movement': 2,
#          'hour': 2,
#          'shown': 2,
#          'private': 2,
#          'Christian': 2,
#          'foreign': 2,
#          'meeting': 2,
#          'likely': 2,
#          'efforts': 2,
#          'character': 2,
#          'attitude': 2,
#          'volume': 2,
#          'sound': 2,
#          'trade': 2,
#          'wrong': 2,
#          'merely': 2,
#          'land': 2,
#          'placed': 2,
#          'ideas': 2,
#          'hope': 2,
#          'manner': 2,
#          'performance': 2,
#          'issue': 2,
#          'countries': 2,
#          'instead': 2,
#          'forces': 2,
#          'thinking': 2,
#          'points': 2,
#          'research': 2,
#          'Thus': 2,
#          'heart': 2,
#          'added': 2,
#          'color': 2,
#          '10': 2,
#          'Department': 2,
#          'cold': 2,
#          'bed': 2,
#          'bad': 2,
#          'market': 2,
#          'understand': 2,
#          'police': 2,
#          'party': 2,
#          'First': 2,
#          'physical': 2,
#          'House': 2,
#          'equipment': 2,
#          'report': 2,
#          'effective': 2,
#          'students': 2,
#          'ways': 2,
#          'defense': 2,
#          'states': 2,
#          'actually': 2,
#          'everything': 2,
#          'complete': 2,
#          'normal': 2,
#          'situation': 2,
#          'obtained': 2,
#          'steps': 2,
#          'cut': 2,
#          'comes': 2,
#          'rate': 2,
#          'particular': 2,
#          'class': 2,
#          'lack': 2,
#          'pay': 2,
#          'aid': 2,
#          'feed': 2,
#          'pool': 2,
#          'pressure': 2,
#          'boys': 2,
#          'former': 2,
#          'directly': 2,
#          'fear': 2,
#          'talk': 2,
#          'Although': 2,
#          '1961': 2,
#          'written': 2,
#          'ten': 2,
#          'certainly': 2,
#          'theory': 2,
#          'finally': 2,
#          'fall': 2,
#          'stock': 2,
#          'wide': 2,
#          'degree': 2,
#          'Another': 2,
#          'followed': 2,
#          'religious': 2,
#          'Aj': 2,
#          'hold': 2,
#          'effort': 2,
#          'says': 2,
#          'programs': 2,
#          'University': 2,
#          'plant': 2,
#          'mother': 2,
#          'ground': 2,
#          'meet': 2,
#          'court': 2,
#          'indicated': 2,
#          'freedom': 2,
#          'Island': 2,
#          'suddenly': 2,
#          'Since': 2,
#          'industry': 2,
#          'activity': 2,
#          'sent': 2,
#          'simply': 2,
#          'hair': 2,
#          'truth': 2,
#          'recent': 2,
#          'St.': 2,
#          'required': 2,
#          'sometimes': 2,
#          'happened': 2,
#          'greater': 2,
#          'literature': 2,
#          'especially': 2,
#          "I've": 2,
#          'nature': 2,
#          'William': 2,
#          'total': 2,
#          'decision': 2,
#          'morning': 2,
#          'red': 2,
#          'understanding': 2,
#          'looking': 2,
#          'fine': 2,
#          'forward': 2,
#          'act': 2,
#          'strong': 2,
#          "man's": 2,
#          'production': 2,
#          'move': 2,
#          'hours': 2,
#          'support': 2,
#          'lay': 2,
#          'West': 2,
#          'main': 2,
#          'return': 2,
#          'view': 2,
#          'approach': 2,
#          'society': 2,
#          'spirit': 2,
#          'ready': 2,
#          'nation': 2,
#          'amount': 2,
#          'showed': 2,
#          'worked': 2,
#          'expected': 2,
#          'served': 2,
#          'received': 2,
#          'million': 2,
#          'War': 2,
#          'beginning': 2,
#          'piece': 2,
#          'rest': 2,
#          'appeared': 2,
#          'plane': 2,
#          'figure': 2,
#          'charge': 2,
#          'stopped': 2,
#          'stand': 2,
#          'except': 2,
#          'trouble': 2,
#          'serious': 2,
#          'cases': 2,
#          '30': 2,
#          'dark': 2,
#          'idea': 2,
#          'Yet': 2,
#          'walked': 2,
#          'range': 2,
#          'building': 2,
#          'months': 2,
#          'road': 2,
#          'decided': 2,
#          'evening': 2,
#          'leave': 2,
#          'fiscal': 2,
#          'eye': 2,
#          'opened': 2,
#          'girls': 2,
#          'start': 2,
#          'England': 2,
#          'working': 2,
#          'feeling': 2,
#          'picture': 2,
#          'person': 2,
#          'economic': 2,
#          'population': 2,
#          'simple': 2,
#          'education': 2,
#          'six': 2,
#          'tried': 2,
#          'gone': 2,
#          'thus': 2,
#          'difficult': 2,
#          'Negro': 2,
#          'remember': 2,
#          'hundred': 2,
#          'lot': 2,
#          'moral': 2,
#          'results': 2,
#          'alone': 2,
#          'strength': 2,
#          'terms': 2,
#          'floor': 2,
#          'black': 2,
#          'including': 2,
#          'stage': 2,
#          'increase': 2,
#          'trying': 2,
#          'deal': 2,
#          '1960': 2,
#          'table': 2,
#          'knowledge': 2,
#          'fire': 2,
#          'Well': 2,
#          'considered': 2,
#          'try': 2,
#          'reading': 2,
#          'book': 2,
#          'increased': 2,
#          'food': 2,
#          'continued': 2,
#          'friend': 2,
#          'chance': 2,
#          '4': 2,
#          'gives': 2,
#          'process': 2,
#          "I'll": 2,
#          'needs': 2,
#          'record': 2,
#          'function': 2,
#          'section': 2,
#          'corner': 2,
#          'temperature': 2,
#          'larger': 2,
#          'English': 2,
#          'systems': 2,
#          'described': 2,
#          'reached': 2,
#          'call': 2,
#          'purpose': 2,
#          'answer': 2,
#          'lower': 2,
#          'letter': 2,
#          'else': 2,
#          'art': 2,
#          'particularly': 2,
#          'hall': 2,
#          'test': 2,
#          'sales': 2,
#          'basis': 2,
#          'father': 2,
#          'taking': 2,
#          'methods': 2,
#          'sat': 2,
#          'trial': 2,
#          'property': 2,
#          'values': 2,
#          "I'd": 2,
#          'third': 2,
#          'weeks': 2,
#          'single': 2,
#          'conditions': 2,
#          'husband': 2,
#          'Kennedy': 2,
#          'women': 2,
#          'beyond': 2,
#          'coming': 2,
#          'training': 2,
#          'miles': 2,
#          'America': 2,
#          'labor': 2,
#          'personal': 2,
#          'near': 2,
#          'couple': 2,
#          'space': 2,
#          'influence': 2,
#          'Secretary': 2,
#          'center': 2,
#          'wrote': 2,
#          'South': 2,
#          'General': 2,
#          'century': 2,
#          'attention': 2,
#          'Many': 2,
#          'step': 2,
#          'questions': 2,
#          'statement': 2,
#          'list': 2,
#          'various': 2,
#          'National': 2,
#          'earth': 2,
#          'met': 2,
#          'developed': 2,
#          'late': 2,
#          'material': 2,
#          'sort': 2,
#          'window': 2,
#          'paid': 2,
#          'addition': 2,
#          'lines': 2,
#          'wall': 2,
#          'returned': 2,
#          'impossible': 1,
#          'intellectual': 1,
#          'Club': 1,
#          'stared': 1,
#          'playing': 1,
#          'ordinary': 1,
#          'C': 1,
#          'angle': 1,
#          'skin': 1,
#          'travel': 1,
#          'Yes': 1,
#          'leaders': 1,
#          'university': 1,
#          'element': 1,
#          'continue': 1,
#          'occasion': 1,
#          'circle': 1,
#          'prices': 1,
#          'walking': 1,
#          'aircraft': 1,
#          'looks': 1,
#          'evil': 1,
#          'text': 1,
#          'billion': 1,
#          'mounted': 1,
#          'annual': 1,
#          'director': 1,
#          'Lord': 1,
#          'personnel': 1,
#          'depth': 1,
#          'apparent': 1,
#          '7': 1,
#          'proud': 1,
#          'content': 1,
#          'boats': 1,
#          'disease': 1,
#          'cattle': 1,
#          'developing': 1,
#          'camp': 1,
#          'leaving': 1,
#          'relief': 1,
#          'highest': 1,
#          'master': 1,
#          'official': 1,
#          'message': 1,
#          'issues': 1,
#          'comfort': 1,
#          'properly': 1,
#          'alive': 1,
#          'Paris': 1,
#          'Perhaps': 1,
#          'park': 1,
#          'seat': 1,
#          'everyone': 1,
#          'goods': 1,
#          'planned': 1,
#          'security': 1,
#          'tone': 1,
#          'R.': 1,
#          'religion': 1,
#          'London': 1,
#          'dictionary': 1,
#          'telephone': 1,
#          'absence': 1,
#          'minimum': 1,
#          'application': 1,
#          'wished': 1,
#          'price': 1,
#          'specific': 1,
#          'share': 1,
#          'teeth': 1,
#          'meant': 1,
#          'Figure': 1,
#          'ahead': 1,
#          'existence': 1,
#          'sweet': 1,
#          'emphasis': 1,
#          'bottle': 1,
#          'broad': 1,
#          'quietly': 1,
#          'gun': 1,
#          'luck': 1,
#          'professional': 1,
#          'World': 1,
#          'Council': 1,
#          'Like': 1,
#          'practices': 1,
#          'emotional': 1,
#          'largest': 1,
#          'associated': 1,
#          'arms': 1,
#          'progress': 1,
#          'running': 1,
#          'ideal': 1,
#          'supported': 1,
#          'diameter': 1,
#          'sky': 1,
#          'millions': 1,
#          'Japanese': 1,
#          'neck': 1,
#          'liberal': 1,
#          'California': 1,
#          'Board': 1,
#          'broken': 1,
#          'Alexander': 1,
#          'poems': 1,
#          'secret': 1,
#          'minute': 1,
#          'Tom': 1,
#          'hardly': 1,
#          'operation': 1,
#          'supply': 1,
#          'anode': 1,
#          'worse': 1,
#          'extra': 1,
#          'writers': 1,
#          'item': 1,
#          'Old': 1,
#          'contrast': 1,
#          'youth': 1,
#          'measurements': 1,
#          'send': 1,
#          'regular': 1,
#          'interests': 1,
#          'sources': 1,
#          'usual': 1,
#          'hopes': 1,
#          'animal': 1,
#          'speaking': 1,
#          'studies': 1,
#          'subjects': 1,
#          'streets': 1,
#          'audience': 1,
#          'pulled': 1,
#          'middle': 1,
#          'offered': 1,
#          'structure': 1,
#          'Finally': 1,
#          'drinking': 1,
#          'chosen': 1,
#          'corporation': 1,
#          'Association': 1,
#          'onto': 1,
#          'rates': 1,
#          'choice': 1,
#          'increases': 1,
#          'limited': 1,
#          'soldiers': 1,
#          'musical': 1,
#          'passage': 1,
#          'Jack': 1,
#          'learned': 1,
#          'imagination': 1,
#          'capital': 1,
#          'charges': 1,
#          'showing': 1,
#          'fell': 1,
#          'wild': 1,
#          'discovered': 1,
#          'Committee': 1,
#          'cry': 1,
#          'spot': 1,
#          'preparation': 1,
#          'characteristics': 1,
#          'headquarters': 1,
#          'surprised': 1,
#          'Great': 1,
#          'post': 1,
#          'Day': 1,
#          'previously': 1,
#          'marriage': 1,
#          'sufficient': 1,
#          'presented': 1,
#          'hotel': 1,
#          'taught': 1,
#          'setting': 1,
#          'Southern': 1,
#          'extent': 1,
#          'C.': 1,
#          'score': 1,
#          'typical': 1,
#          'aspects': 1,
#          'highly': 1,
#          '100': 1,
#          'vacation': 1,
#          'agencies': 1,
#          'rare': 1,
#          'deny': 1,
#          'River': 1,
#          'index': 1,
#          'pick': 1,
#          'maintain': 1,
#          'Alfred': 1,
#          'dream': 1,
#          'language': 1,
#          'enjoyed': 1,
#          'medical': 1,
#          'fast': 1,
#          'latter': 1,
#          'fashion': 1,
#          'pounds': 1,
#          'rapid': 1,
#          'College': 1,
#          'membership': 1,
#          'drawn': 1,
#          'Khrushchev': 1,
#          'platform': 1,
#          'smoke': 1,
#          'join': 1,
#          'brown': 1,
#          '25': 1,
#          'noted': 1,
#          'October': 1,
#          'possibility': 1,
#          'Morgan': 1,
#          'dogs': 1,
#          'fill': 1,
#          'hell': 1,
#          'fields': 1,
#          'realize': 1,
#          'tomorrow': 1,
#          'etc.': 1,
#          'traffic': 1,
#          'roof': 1,
#          'note': 1,
#          'essential': 1,
#          'energy': 1,
#          'additional': 1,
#          'spirits': 1,
#          'Boston': 1,
#          'shows': 1,
#          'purposes': 1,
#          'Hanover': 1,
#          'climbed': 1,
#          'wish': 1,
#          'sounds': 1,
#          'Latin': 1,
#          'ask': 1,
#          'train': 1,
#          'whatever': 1,
#          '16': 1,
#          'establish': 1,
#          'grow': 1,
#          'located': 1,
#          'editor': 1,
#          'handle': 1,
#          'changed': 1,
#          'individuals': 1,
#          'difficulties': 1,
#          'Though': 1,
#          'Rhode': 1,
#          'poetry': 1,
#          'loose': 1,
#          'somewhat': 1,
#          'somewhere': 1,
#          'knows': 1,
#          'railroad': 1,
#          'dinner': 1,
#          'tradition': 1,
#          'letters': 1,
#          'income': 1,
#          'regard': 1,
#          'sample': 1,
#          'solution': 1,
#          'writing': 1,
#          'target': 1,
#          '60': 1,
#          'closely': 1,
#          'demands': 1,
#          'boat': 1,
#          'Army': 1,
#          ...})

# %% [markdown]
# ## 4. Model
#
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
def prepare_sequence(seq, word2index):
    idxs = list(map(lambda w: word2index[w] if word2index.get(w) is not None else word2index['<UNK>'], seq))
    return torch.LongTensor(idxs)

# %%
import random

def negative_sampling(targets, unigram_table, k):
    batch_size = targets.shape[0]
    neg_samples = []
    for i in range(batch_size):  #(1, k)
        target_index = targets[i].item()
        nsample      = []
        while (len(nsample) < k):
            neg = random.choice(unigram_table)
            if word2index[neg] == target_index:
                continue
            nsample.append(neg)
        neg_samples.append(prepare_sequence(nsample, word2index).reshape(1, -1))
        
    return torch.cat(neg_samples) #batch_size, k

# %%
batch_size = 2
x, y = random_batch(batch_size, corpus)
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)

# %%
k = 5
neg_samples = negative_sampling(y_tensor, unigram_table, k)

# %%
y_tensor[1]
# Out:
# tensor([6247])

# %%
neg_samples[1]
# Out:
# tensor([1262, 8441, 4111, 4774, 5166])

# %% [markdown]
# $$\mathbf{J}_{\text{neg-sample}}(\mathbf{v}_c,o,\mathbf{U})=-\log(\sigma(\mathbf{u}_o^T\mathbf{v}_c))-\sum_{k=1}^K\log(\sigma(-\mathbf{u}_k^T\mathbf{v}_c))$$

# %%
class SkipgramNeg(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(SkipgramNeg, self).__init__()
        self.embedding_center  = nn.Embedding(voc_size, emb_size)
        self.embedding_outside = nn.Embedding(voc_size, emb_size)
        self.logsigmoid        = nn.LogSigmoid()
    
    def forward(self, center, outside, negative):
        #center, outside:  (bs, 1)
        #negative       :  (bs, k)
        
        center_embed   = self.embedding_center(center) #(bs, 1, emb_size)
        outside_embed  = self.embedding_outside(outside) #(bs, 1, emb_size)
        negative_embed = self.embedding_outside(negative) #(bs, k, emb_size)
        
        uovc           = outside_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, 1)
        ukvc           = -negative_embed.bmm(center_embed.transpose(1, 2)).squeeze(2) #(bs, k)
        ukvc_sum       = torch.sum(ukvc, 1).reshape(-1, 1) #(bs, 1)
        
        loss           = self.logsigmoid(uovc) + self.logsigmoid(ukvc_sum)
        
        return -torch.mean(loss)

# %%
#test your model
emb_size = 2
voc_size = len(vocabs)
model = SkipgramNeg(voc_size, emb_size)

# %%
loss = model(x_tensor, y_tensor, neg_samples)

# %%
loss
# Out:
# tensor(1.9709, grad_fn=<NegBackward0>)

# %% [markdown]
# ## 5. Training

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
start = time.time()
num_epochs = 1000
window_size = 5

for epoch in range(num_epochs):
    
    #get batch
    input_batch, label_batch = random_batch(batch_size, corpus, window_size)
    input_tensor = torch.LongTensor(input_batch)
    label_tensor = torch.LongTensor(label_batch)
    
    #predict
    neg_samples = negative_sampling(label_tensor, unigram_table, k)
    loss = model(input_tensor, label_tensor, neg_samples)
    
    #backprogate
    optimizer.zero_grad()
    loss.backward()
    
    #update alpha
    optimizer.step()

    epoch_mins, epoch_secs = epoch_time(start, time.time())
    
    #print the loss
    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | Loss: {loss:.6f} | Time: {epoch_mins}m {epoch_secs}s")
# Out:
# Epoch: 100 | Loss: 1.588514 | Time: 1m 25s
# Epoch: 200 | Loss: 3.085959 | Time: 2m 47s
# Epoch: 300 | Loss: 1.704542 | Time: 4m 4s
# Epoch: 400 | Loss: 1.667598 | Time: 5m 21s
# Epoch: 500 | Loss: 2.005045 | Time: 6m 40s
# Epoch: 600 | Loss: 1.940446 | Time: 7m 57s
# Epoch: 700 | Loss: 0.862773 | Time: 9m 11s
# Epoch: 800 | Loss: 3.457966 | Time: 10m 15s
# Epoch: 900 | Loss: 1.680911 | Time: 11m 22s
# Epoch: 1000 | Loss: 3.272110 | Time: 12m 30s

# %% [markdown]
# ## 6. Plot the embeddings

# %%
vocabs
# Out:
# ['assumptions',
#  'impossible',
#  'Boys',
#  'worn',
#  'intellectual',
#  'Club',
#  'Market',
#  'French',
#  'rope',
#  'however',
#  'Turkish',
#  'stared',
#  'sponsored',
#  'slipped',
#  'proof',
#  'age',
#  'Dr.',
#  'Colorado',
#  'emotions',
#  'earlier',
#  'Nelson',
#  'eloquent',
#  'playing',
#  'register',
#  'concepts',
#  'Monroe',
#  'compiled',
#  'One',
#  'tremendous',
#  'direction',
#  'Publications',
#  'ordinary',
#  'C',
#  'Chapel',
#  'angle',
#  'theology',
#  'contributions',
#  'era',
#  'Academy',
#  'vertical',
#  'skin',
#  'waving',
#  'singers',
#  'blunt',
#  'live',
#  'react',
#  'Achievement',
#  'adjust',
#  'lump',
#  'Youth',
#  'theoretical',
#  'springs',
#  'selfish',
#  'decides',
#  'watercolor',
#  'remind',
#  'Turning',
#  'slice',
#  'lead',
#  'travel',
#  'sake',
#  'Yes',
#  'Joseph',
#  'remark',
#  'leaders',
#  'surrendered',
#  'Dumont',
#  'supplied',
#  'approaching',
#  'honors',
#  'camera',
#  'university',
#  'acted',
#  'element',
#  'neurotic',
#  'match',
#  'FBI',
#  'filtered',
#  'consistent',
#  'phenomena',
#  'brighter',
#  'name',
#  'H',
#  'Gen.',
#  "Can't",
#  'continue',
#  'farmers',
#  'conjunction',
#  'shut',
#  'Following',
#  'Mass',
#  'northeast',
#  'multiplicity',
#  'swelling',
#  'occasion',
#  'map',
#  'aborigines',
#  'Tony',
#  'biological',
#  'circle',
#  'Lucy',
#  'Unless',
#  'contempt',
#  'Copernican',
#  'bride',
#  'housing',
#  'returns',
#  'prices',
#  'Week',
#  'Whenever',
#  'sentence',
#  'walking',
#  'paths',
#  'conventions',
#  'adolescent',
#  'dashed',
#  '1832',
#  'aircraft',
#  'kingdom',
#  'Guard',
#  'communicative',
#  'grand',
#  'privileges',
#  'looks',
#  'sites',
#  'ballet',
#  'prominently',
#  'suitcase',
#  'emptied',
#  'evil',
#  'parent',
#  'text',
#  'heater',
#  'buffer',
#  'Bake',
#  'precisely',
#  'choices',
#  'indicators',
#  'warming',
#  'depending',
#  'stretched',
#  'elimination',
#  'Lauro',
#  "1/4''",
#  'Soviet',
#  'billion',
#  'completely',
#  'muzzle',
#  'enthusiasm',
#  'mounted',
#  'Drexel',
#  'service',
#  '150',
#  'Jersey',
#  'growth',
#  'Kayabashi',
#  'Krim',
#  'ironic',
#  'couples',
#  'chin',
#  'oils',
#  'convenience',
#  'sensual',
#  'hazards',
#  'illusion',
#  'departing',
#  'scholarships',
#  'momentum',
#  'pause',
#  'attacks',
#  'irregular',
#  'actuality',
#  'accessories',
#  'annual',
#  'gloves',
#  'Eastern',
#  'director',
#  'illness',
#  'indirect',
#  'ridge',
#  'Lord',
#  'personnel',
#  'Hub',
#  'sheer',
#  'Anniston',
#  'brains',
#  'correspondent',
#  'silence',
#  'depth',
#  'drastically',
#  'composers',
#  'Side',
#  'innocence',
#  'apparent',
#  'unconsciously',
#  'Ramsey',
#  'literally',
#  'achievements',
#  'piled',
#  'Suddenly',
#  'Johnston',
#  'vector',
#  'doll',
#  'hauled',
#  'judge',
#  'Hoag',
#  'almost',
#  'forty-four',
#  '7',
#  'Marshal',
#  'masses',
#  'spy',
#  'therapist',
#  'positivist',
#  'proud',
#  'predict',
#  'fluids',
#  'moved',
#  'Beverly',
#  'Andy',
#  'collar',
#  'elegance',
#  'messages',
#  'sixteen',
#  'ceiling',
#  'convention',
#  'suffering',
#  'misfortune',
#  'Shakespeare',
#  'breath',
#  'pit',
#  'content',
#  'reverse',
#  'Queen',
#  'easier',
#  'falling',
#  'implied',
#  'contacts',
#  'cultural',
#  'texture',
#  'Anglo-Saxon',
#  'swear',
#  'enthusiastic',
#  'Bridge',
#  'expressions',
#  'uneasy',
#  'given',
#  'word',
#  'wool',
#  'plowing',
#  'performances',
#  'dusty',
#  'dressing',
#  'bolt',
#  'musician',
#  'tongue',
#  'colorful',
#  'boats',
#  'bruised',
#  'People',
#  "we'll",
#  'disease',
#  'cattle',
#  'substances',
#  'violently',
#  'secant',
#  'conclusions',
#  'Tommy',
#  'X',
#  'Fourth',
#  'disposed',
#  'yarns',
#  'popularity',
#  'anyone',
#  'developing',
#  'camp',
#  'Accordingly',
#  'shelters',
#  'salesmen',
#  'mayor',
#  'leaving',
#  'Using',
#  'excellence',
#  'tobacco',
#  'deliberate',
#  'v.',
#  'chaos',
#  'relief',
#  'highest',
#  'dozen',
#  'compensation',
#  'master',
#  'mechanism',
#  "bull's-eyes",
#  'official',
#  'volunteer',
#  'tracing',
#  'Ryan',
#  "Hudson's",
#  'collapsed',
#  'nursing',
#  'objections',
#  'deemed',
#  'joint',
#  'costume',
#  'message',
#  'joys',
#  'hairs',
#  'credited',
#  'average',
#  'forecasting',
#  'hats',
#  'sweep',
#  'issues',
#  'comfort',
#  'comments',
#  'claiming',
#  'applause',
#  'undertaken',
#  'Perry',
#  'Mother',
#  'community',
#  'cost',
#  'deputy',
#  'verdict',
#  'properly',
#  'anecdote',
#  'banished',
#  'conjugates',
#  'representative',
#  'access',
#  'acquisition',
#  'Hank',
#  'troubled',
#  'completion',
#  'warmly',
#  'job',
#  'connected',
#  'rated',
#  'changes',
#  'bothered',
#  'skywave',
#  'Horn',
#  'alive',
#  'Paris',
#  'Perhaps',
#  'park',
#  'weakness',
#  'metaphysical',
#  'sloping',
#  "She'll",
#  'ladder',
#  'Holy',
#  'catastrophe',
#  'Kate',
#  'locks',
#  'marijuana',
#  'seat',
#  'recommendation',
#  'McCormick',
#  'everyone',
#  'capture',
#  'forecast',
#  'goods',
#  'disguised',
#  'occupation',
#  'planned',
#  'shoved',
#  'security',
#  'observer',
#  'starvation',
#  'reception',
#  'tone',
#  'embodiment',
#  'one',
#  'outlook',
#  'murders',
#  'Word',
#  '200',
#  'drifted',
#  'jerked',
#  'restrictions',
#  'decoration',
#  'Cologne',
#  'Tessie',
#  'Harry',
#  'ministers',
#  'R.',
#  'consecutive',
#  'Testament',
#  'spare',
#  'Yankee',
#  'quantities',
#  'fascinated',
#  "Christ's",
#  'burned',
#  'communism',
#  'denoted',
#  'spectators',
#  'peace',
#  'Cotton',
#  'body',
#  'museum',
#  'caliber',
#  'religion',
#  'turnpikes',
#  'London',
#  'contented',
#  'cited',
#  'worried',
#  'ninety',
#  'distributed',
#  'Jews',
#  'dice',
#  'straightforward',
#  'summers',
#  'diagram',
#  'longer',
#  'dictionary',
#  'schoolhouse',
#  'lonely',
#  'unpopular',
#  'Additional',
#  'telephone',
#  'draft',
#  'flag',
#  'absence',
#  'minimum',
#  'swayed',
#  'application',
#  'Spencer',
#  'steadily',
#  'Amen',
#  'newcomer',
#  'productivity',
#  'Son',
#  'wished',
#  'advise',
#  'butyrate',
#  'Mrs.',
#  '32',
#  'frustration',
#  'sharply',
#  'price',
#  'graceful',
#  'Nick',
#  'ill',
#  'bin',
#  'Alec',
#  'twentieth',
#  'vines',
#  'motif',
#  'murdered',
#  'Carla',
#  'bacterial',
#  'characters',
#  'natives',
#  'line',
#  'cutters',
#  'phony',
#  'development',
#  'courtesy',
#  'specific',
#  'share',
#  'perform',
#  'ultrasonic',
#  'complement',
#  'UN',
#  'virtue',
#  'dazzling',
#  'Nicolas',
#  'dining',
#  'plow',
#  'refuse',
#  'dealing',
#  'thing',
#  '1/2',
#  'slower',
#  'Prince',
#  'vegetables',
#  'Rogers',
#  'magazines',
#  'withholding',
#  'Stuart',
#  'instrumental',
#  'juvenile',
#  'know',
#  'mercury',
#  'reign',
#  'receives',
#  'inquired',
#  'subject',
#  'teeth',
#  'mood',
#  'eleven',
#  'violation',
#  'nurse',
#  'mixed',
#  'creek',
#  'wave',
#  'basement',
#  'Hengesbach',
#  'packaging',
#  'boast',
#  'Buck',
#  'lengths',
#  'emotion',
#  'Stevie',
#  'Steichen',
#  'mean',
#  "they'd",
#  'preventing',
#  'decency',
#  'adult',
#  'taken',
#  'childhood',
#  'construct',
#  'exciting',
#  'border',
#  'makes',
#  'leveling',
#  'filing',
#  'involving',
#  'pretending',
#  'moods',
#  'infrared',
#  'Miller',
#  'meant',
#  'belly',
#  'swinging',
#  'Figure',
#  'cafe',
#  'parade',
#  'tables',
#  'naked',
#  'corporate',
#  'defensive',
#  'fame',
#  'adds',
#  'feared',
#  'pleased',
#  '1953',
#  'vitamins',
#  'associations',
#  'eagerly',
#  'exploration',
#  'Styka',
#  'absorbed',
#  'ahead',
#  'stake',
#  'existence',
#  'conferences',
#  'maximization',
#  '1949',
#  'wheeled',
#  'sweet',
#  'bounced',
#  'noting',
#  'brightness',
#  'superiority',
#  'secretary',
#  'glad',
#  'eyed',
#  'emphasis',
#  'attended',
#  'tours',
#  'Indonesia',
#  'sampling',
#  'Spirit',
#  'conservative',
#  'Jenkins',
#  'indicates',
#  'earliest',
#  'lacks',
#  'fond',
#  'collapse',
#  'bottle',
#  'getting',
#  'covers',
#  'York',
#  'Atlantic',
#  'armed',
#  'drainage',
#  'following',
#  'numbered',
#  'beans',
#  'tax',
#  'Angels',
#  '1940',
#  'branch',
#  'departure',
#  'denying',
#  'Funeral',
#  'summer',
#  'fix',
#  'mailed',
#  'noble',
#  'informal',
#  'sailors',
#  'broad',
#  'exhaust',
#  'quietly',
#  'territorial',
#  'distal',
#  'part',
#  'sterile',
#  'technical',
#  'Benington',
#  'Rayburn',
#  'Mass.',
#  'offers',
#  'Joyce',
#  'voting',
#  'gun',
#  'gained',
#  'departments',
#  'collectors',
#  'Last',
#  'boots',
#  'supporters',
#  'projections',
#  'major',
#  'detectives',
#  'prevents',
#  'luck',
#  'antibody',
#  'pending',
#  'analogy',
#  'professional',
#  'reproduce',
#  'hastily',
#  'Duke',
#  'Gloucester',
#  'humming',
#  'World',
#  'aboard',
#  'revolver',
#  'use',
#  'designated',
#  'Library',
#  'hut',
#  'Council',
#  'butter',
#  'Bourbons',
#  'classic',
#  'Like',
#  'extend',
#  'Love',
#  'ambition',
#  'silk',
#  'pro-Western',
#  'slavery',
#  'transparent',
#  'Y.',
#  'contrasts',
#  'two-thirds',
#  'bore',
#  'tools',
#  'drawing',
#  'speeches',
#  'domination',
#  'Brenner',
#  'outfit',
#  'congruence',
#  'practices',
#  'valued',
#  'minutes',
#  'alienation',
#  'entire',
#  'halted',
#  'gardens',
#  'emotional',
#  'glorious',
#  'orderly',
#  'board',
#  'largest',
#  'much',
#  'associated',
#  'Jackson',
#  'arms',
#  'Lilly',
#  'fly',
#  'hiding',
#  'realtors',
#  'surgeon',
#  'competing',
#  'restrict',
#  'producing',
#  'admiration',
#  'guards',
#  'occurs',
#  'full',
#  'joy',
#  'casually',
#  'furnishings',
#  'partisan',
#  'plot',
#  'wit',
#  'internal',
#  'progress',
#  'vicinity',
#  'neutral',
#  'running',
#  'computed',
#  '2:37',
#  'obligation',
#  'amplifier',
#  'ideal',
#  'supported',
#  'diameter',
#  'Barco',
#  'devised',
#  'sky',
#  'Development',
#  'bones',
#  'terror',
#  'millions',
#  'stranded',
#  'instructions',
#  'vapor',
#  'chapel',
#  'Warsaw',
#  'assuring',
#  'edges',
#  'Labor',
#  'magnetic',
#  'Japanese',
#  'reform',
#  'ordinarily',
#  'neck',
#  'liberal',
#  'Production',
#  'smoothly',
#  'compromise',
#  'flew',
#  'California',
#  'Tilghman',
#  'Board',
#  'even',
#  'bring',
#  'wholly',
#  'advised',
#  'although',
#  'Washington',
#  'heartily',
#  'ponds',
#  'tank',
#  'glasses',
#  'elevated',
#  'worship',
#  'stability',
#  'initially',
#  'shy',
#  'elder',
#  'peril',
#  'sovereignty',
#  'wounded',
#  'anniversary',
#  'conscious',
#  'mock',
#  'detergent',
#  'yelled',
#  'impose',
#  'Wally',
#  'love',
#  'incentive',
#  'utility',
#  'broken',
#  'finest',
#  'evenings',
#  'cats',
#  'drum',
#  'referring',
#  'Laura',
#  'mob',
#  'graph',
#  'visited',
#  'Hoot',
#  'Alexander',
#  'Virgin',
#  'Considering',
#  'discussions',
#  'routes',
#  'monkey',
#  'landed',
#  'metallic',
#  'drunken',
#  'led',
#  'poems',
#  'immediately',
#  'cosmetics',
#  'arrangements',
#  'slaughter',
#  'might',
#  'smashed',
#  'exert',
#  'ultimately',
#  'profit',
#  'respiratory',
#  'beef',
#  'readings',
#  'estimate',
#  'individualism',
#  'wagons',
#  'Hero',
#  'manifold',
#  'soiled',
#  'Gilborn',
#  'figured',
#  'secret',
#  'circles',
#  'farming',
#  'homer',
#  'Much',
#  'Holmes',
#  'prosperity',
#  'portions',
#  'glancing',
#  'pays',
#  'minute',
#  'immense',
#  'trials',
#  'clubs',
#  'compost',
#  'grammatical',
#  'Tom',
#  'royal',
#  'mice',
#  'Dick',
#  'divorce',
#  "We're",
#  'marriages',
#  'satisfaction',
#  'well-being',
#  'deeply',
#  'coach',
#  'sticking',
#  'Exchange',
#  'horse',
#  'incredibly',
#  'low',
#  'give',
#  'lagoon',
#  'hardly',
#  'operation',
#  'mail',
#  'adjoining',
#  'supply',
#  'notable',
#  'leaf',
#  'chill',
#  'masters',
#  "President's",
#  'insisted',
#  'injuries',
#  'anode',
#  'size',
#  'worse',
#  'true',
#  'virus',
#  'softly',
#  'grip',
#  'extra',
#  'directing',
#  'shrill',
#  'pushing',
#  'wife',
#  'writers',
#  'ethnic',
#  'gentle',
#  "Barco's",
#  'keeps',
#  'servant',
#  'expand',
#  'U',
#  'volumes',
#  'item',
#  'granting',
#  'inspired',
#  'Show',
#  'Aristotle',
#  'daughters',
#  'Hawaii',
#  'formulations',
#  'founded',
#  'wire',
#  'entering',
#  'accident',
#  'determination',
#  'pockets',
#  'Stanley',
#  'proportional',
#  'chain',
#  'balanced',
#  'odors',
#  'Republicans',
#  'reaches',
#  'bags',
#  'toast',
#  'gum',
#  'whispered',
#  'Presidential',
#  'Old',
#  '8,000',
#  'probable',
#  'fleeing',
#  'stomach',
#  'bottles',
#  'contrast',
#  'pear',
#  'religions',
#  'notify',
#  'beer',
#  'insist',
#  'reservoir',
#  'destroying',
#  'accurately',
#  'hardship',
#  'upon',
#  'done',
#  'Completion',
#  'forty',
#  'anaconda',
#  'Papa-san',
#  'Midwest',
#  'child',
#  'perceptions',
#  'youth',
#  'measurements',
#  'hard',
#  'cease',
#  'thirteen',
#  'supplying',
#  'month',
#  'send',
#  'regular',
#  'stillness',
#  'Staff',
#  'traces',
#  'inherited',
#  'retention',
#  'Langford',
#  "Welch's",
#  'intonation',
#  'iodide',
#  'Diana',
#  'polarization',
#  'guilt',
#  'scrap',
#  '0.5',
#  'proceedings',
#  'titled',
#  "He'd",
#  'Legislature',
#  'vivid',
#  'interests',
#  'wondering',
#  'hypothalamic',
#  'generators',
#  'brought',
#  'Ruanda-Urundi',
#  'invested',
#  'Powell',
#  "an'",
#  'purely',
#  'shed',
#  'studio',
#  'sources',
#  'visit',
#  "Miller's",
#  'flu',
#  "woman's",
#  'Hitler',
#  "patient's",
#  'scheduled',
#  'wanting',
#  'usual',
#  'expressing',
#  'welcome',
#  'Glendora',
#  'aesthetic',
#  'Sergeant',
#  'natural',
#  'frowned',
#  'assessed',
#  'darkened',
#  'spreading',
#  'Burton',
#  'hopes',
#  'animal',
#  'Would',
#  'hillside',
#  'speaking',
#  'troop',
#  'Timothy',
#  'Piepsam',
#  'manifest',
#  'introduction',
#  'fired',
#  'studies',
#  ...]

# %%
fish = torch.LongTensor([word2index['fish']])
fish
# Out:
# tensor([8667])

# %%
fish_embed_c = model.embedding_center(fish)
fish_embed_o = model.embedding_outside(fish)
fish_embed   = (fish_embed_c + fish_embed_o) / 2
fish_embed
# Out:
# tensor([[ 0.6047, -0.8883]], grad_fn=<DivBackward0>)

# %%
fish_embed_o
# Out:
# tensor([[ 0.4870, -2.2891]], grad_fn=<EmbeddingBackward0>)

# %%
def get_embed(word):
    try:
        index = word2index[word]
    except:
        index = word2index['<UNK>']
        
    word = torch.LongTensor([word2index[word]])
    
    embed_c = model.embedding_center(word)
    embed_o = model.embedding_outside(word)
    embed   = (embed_c + embed_o) / 2
    
    return embed[0][0].item(), embed[0][1].item()

# %%
get_embed('fruit')
# Out:
# (-1.3676352500915527, 0.11526966840028763)

# %%
get_embed('cat')
# Out:
# (0.09021466970443726, 0.2356942594051361)

# %%
get_embed('dog')
# Out:
# (-0.9168112277984619, -0.5291646718978882)

# %%
get_embed('fish')
# Out:
# (0.6047122478485107, -0.888310432434082)

# %% [markdown]
# ## 7. Cosine similarity

# %%
fish = get_embed('fish')
fish
# Out:
# (0.6047122478485107, -0.888310432434082)

# %%
fruit = get_embed('fruit')
fruit
# Out:
# (-1.3676352500915527, 0.11526966840028763)

# %%
cat = get_embed('cat')
cat
# Out:
# (0.09021466970443726, 0.2356942594051361)

# %%
np.array(fish) @ np.array(cat)
# Out:
# -0.15481575378852597

# %%
#more formally is to divide by its norm
def cosine_similarity(A, B):
    dot_product = np.dot(A, B)
    norm_a = np.linalg.norm(A)
    norm_b = np.linalg.norm(B)
    similarity = dot_product / (norm_a * norm_b)
    return similarity

print(cosine_similarity(np.array(fish), np.array(cat)))
print(cosine_similarity(np.array(fish), np.array(fruit)))
# Out:
# -0.5708601653476716
# -0.6301688250982604

# %%
# Create a pickle of the model
import pickle

with open('../../app/models/skipgram_neg/skipgram_neg.pkl', 'wb') as f:
    pickle.dump(model, f)

with open('../../app/models/skipgram_neg/skipgram_neg_word2index.pkl', 'wb') as f:
    pickle.dump(word2index, f)

with open('../../app/models/skipgram_neg/skipgram_neg_index2word.pkl', 'wb') as f:
    pickle.dump(index2word, f)
