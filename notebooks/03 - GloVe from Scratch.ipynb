# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import Counter
from string import punctuation
from scipy import spatial
import math
import time
from itertools import combinations_with_replacement

# %%
import nltk
from nltk.corpus import brown
from nltk.corpus import stopwords
import matplotlib
nltk.download('stopwords')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\swara\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\swara\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %% [markdown]
# ## 1. Load data

# %%
corpus = brown.sents()

# %%
stop_words = set(stopwords.words('english'))
corpus = [[word for word in sent if word.lower() not in stop_words] for sent in corpus]

# Remove punctuation from corpus
corpus = [[word for word in sent if word not in punctuation] for sent in corpus]

# Remove empty sentences
corpus = [sent for sent in corpus if len(sent) > 0]

# Remove sentences with less than 5 words
corpus = [sent for sent in corpus if len(sent) >= 5]

# Remove sentences with more than 20 words
corpus = [sent for sent in corpus if len(sent) <= 20]

# Remove rare words
word_freq = Counter([word for sent in corpus for word in sent])
corpus = [[word for word in sent if word_freq[word] > 5] for sent in corpus]

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))
vocab
# Out:
# ['A.L.A.M.',
#  'presumably',
#  'Moon',
#  'conferences',
#  'leg',
#  'denominations',
#  'memory',
#  'assistance',
#  'two',
#  'route',
#  'sewage',
#  'calculated',
#  'revenge',
#  'Authority',
#  'four',
#  'concepts',
#  'dolls',
#  'intentions',
#  'flashes',
#  'tsunami',
#  'specimen',
#  'Federation',
#  'chin',
#  'clinging',
#  'oven',
#  'mg/l',
#  'overly',
#  'eighteen',
#  'eleven',
#  'Others',
#  'prevention',
#  'compete',
#  'passion',
#  'integrate',
#  'concerto',
#  'cousin',
#  'table',
#  'parked',
#  'supplies',
#  'Today',
#  'examining',
#  'proclamation',
#  'Wally',
#  'dressing',
#  'SBA',
#  'evaluating',
#  'references',
#  'sampled',
#  'wrinkles',
#  "Patchen's",
#  'opportunity',
#  'issued',
#  'cutting',
#  'wires',
#  'hurry',
#  'explosion',
#  'bearing',
#  'pockets',
#  'Richardson',
#  'illustrated',
#  'Gardens',
#  'recommending',
#  'dubious',
#  'forthcoming',
#  'Kirby',
#  'disease',
#  'tourists',
#  'realistically',
#  'tense',
#  'prices',
#  'screens',
#  'fostered',
#  'poetry',
#  'months',
#  'novel',
#  'aboard',
#  'present',
#  'bankers',
#  'Frankie',
#  'gravel',
#  'Andrew',
#  'forgotten',
#  'Federal',
#  'fairly',
#  'fats',
#  'adults',
#  'excitedly',
#  'Italians',
#  'inescapable',
#  'City',
#  'growing',
#  'necessity',
#  'author',
#  'arranged',
#  'grinning',
#  'Star',
#  'Miriam',
#  'consequence',
#  'promoting',
#  'equations',
#  'Legislature',
#  'wages',
#  'Menshikov',
#  'indignation',
#  'Bishop',
#  'ways',
#  'limiting',
#  'appearing',
#  'natives',
#  'X',
#  'factories',
#  'aerial',
#  'struggled',
#  'channels',
#  'instruments',
#  'brick',
#  '4',
#  "o'clock",
#  'box',
#  'Hampshire',
#  'curious',
#  'mixing',
#  'choices',
#  'pressure',
#  'engagements',
#  'Stadium',
#  'earthy',
#  'ambiguity',
#  'Eastern',
#  'accurate',
#  'wave',
#  'cottage',
#  'comfortably',
#  'Atlantic',
#  'Jimmy',
#  'recruit',
#  'heartily',
#  'coffee',
#  'relationships',
#  'absorbed',
#  'lend',
#  'grain',
#  'feed',
#  'cards',
#  'nitrogen',
#  'cargo',
#  'negotiating',
#  'carpenter',
#  'Organization',
#  'defeat',
#  'dictatorship',
#  'Ave.',
#  'theme',
#  'squeezed',
#  'nomination',
#  'proposing',
#  'detached',
#  'suggesting',
#  'Nassau',
#  'benefit',
#  'lawyer',
#  'style',
#  'Lincoln',
#  'phosphor',
#  'inference',
#  'converted',
#  'selections',
#  'rate',
#  'spinning',
#  'novels',
#  'honesty',
#  'teachers',
#  'free',
#  'Meanwhile',
#  'Still',
#  'Edward',
#  'returned',
#  'boards',
#  'ambulance',
#  'flew',
#  'learn',
#  'Also',
#  'supernatural',
#  'bond',
#  'ancestry',
#  'appreciated',
#  'center',
#  'Southerners',
#  'consists',
#  'incentive',
#  'show',
#  'flesh',
#  'trick',
#  'assign',
#  'decreased',
#  'irradiation',
#  'chairs',
#  'boost',
#  'assumes',
#  'Robert',
#  'packing',
#  'lines',
#  'orbit',
#  "State's",
#  'votes',
#  'photographic',
#  'attorney',
#  'micrometeorite',
#  'Would',
#  'expert',
#  'tactics',
#  'clergyman',
#  'limit',
#  'explicit',
#  'bronze',
#  'Hotel',
#  'glorious',
#  'scraped',
#  'relief',
#  'wore',
#  'acquainted',
#  'straightforward',
#  'Maude',
#  'faces',
#  'succession',
#  'probably',
#  'Dec.',
#  'energetic',
#  'benefits',
#  'Sons',
#  '110',
#  'prevented',
#  'doubling',
#  'ninety',
#  'sooner',
#  'shattered',
#  'replacement',
#  'divorce',
#  'external',
#  'burn',
#  'characterized',
#  'biography',
#  'Bridge',
#  'accustomed',
#  'fulfill',
#  'handicap',
#  'Swift',
#  'ripped',
#  'tender',
#  '1930',
#  'necessary',
#  'electricity',
#  'writing',
#  'passages',
#  'stirring',
#  'anecdote',
#  'irregular',
#  "Papa's",
#  'achieving',
#  'intelligible',
#  'combines',
#  'illumination',
#  'components',
#  'call',
#  'hotels',
#  'stamp',
#  'Lester',
#  'mathematics',
#  'Next',
#  'applicable',
#  'conclusion',
#  'lore',
#  'column',
#  'hear',
#  'Victor',
#  'intuition',
#  'negative',
#  'plane',
#  'brother',
#  'Wisconsin',
#  'callous',
#  'war',
#  'operand',
#  'periods',
#  'modify',
#  'initiative',
#  'shaken',
#  'picket',
#  'seen',
#  'Crombie',
#  'neglected',
#  'manners',
#  'token',
#  'lightning',
#  'compulsive',
#  'forests',
#  'findings',
#  'cylinders',
#  'Deegan',
#  'Kodyke',
#  'guarantees',
#  'Pulley',
#  'corporations',
#  'Jew',
#  'juice',
#  'narrowed',
#  'colorful',
#  'rice',
#  'exposure',
#  'birthday',
#  'vitamins',
#  'deduced',
#  'inquiries',
#  'wounded',
#  'educated',
#  'respectable',
#  'comprehensive',
#  'dropping',
#  'nature',
#  'particularly',
#  "Mann's",
#  'visitor',
#  'banks',
#  'Times',
#  'lap',
#  'killed',
#  'performing',
#  'repeating',
#  'Eden',
#  'ambassador',
#  'strewn',
#  'glanced',
#  'military',
#  'red',
#  'Nevertheless',
#  'document',
#  'Af',
#  'Lalaurie',
#  'Madden',
#  'ironic',
#  'Stone',
#  'key',
#  'disarmament',
#  'psychologists',
#  'haste',
#  'strikes',
#  'magnetism',
#  'hollow',
#  'T.',
#  'founding',
#  'bow',
#  'chromatic',
#  'Eve',
#  'revolutionary',
#  'sights',
#  'entered',
#  'taut',
#  'Sandburg',
#  'warnings',
#  'hats',
#  'presentations',
#  'contains',
#  'enemies',
#  'Anthony',
#  'relationship',
#  'continuity',
#  'generators',
#  'Englishmen',
#  'strand',
#  'pack',
#  'utilizing',
#  "poet's",
#  'transformation',
#  'tasted',
#  'arguing',
#  'Union',
#  'however',
#  'Angie',
#  'Van',
#  'vertical',
#  '1,000',
#  'thermometer',
#  'hair',
#  '0.5',
#  'characterization',
#  'couples',
#  'greatness',
#  'elimination',
#  'turned',
#  'stopped',
#  'Pohl',
#  'Boys',
#  'players',
#  'settled',
#  'contributing',
#  'approval',
#  'apparent',
#  'tells',
#  "B'dikkat",
#  'Chester',
#  'exhibited',
#  '17th',
#  'comprise',
#  'Madame',
#  'Square',
#  'essential',
#  'discrimination',
#  'whiskey',
#  'Dallas',
#  'Ada',
#  'chairmen',
#  'wishes',
#  'evaluation',
#  'received',
#  'judged',
#  'actually',
#  'campus',
#  'responded',
#  'sensitivity',
#  'House',
#  'power',
#  'seventeen',
#  'Bank',
#  'increasing',
#  'December',
#  'Expressway',
#  '24',
#  "car's",
#  'inserted',
#  'mothers',
#  'sentenced',
#  'Local',
#  'shipping',
#  'glancing',
#  'incredible',
#  'equitable',
#  'pill',
#  'notice',
#  'needs',
#  'slept',
#  'E.',
#  'frail',
#  'reasons',
#  'Katie',
#  'pointed',
#  'polarization',
#  'addressing',
#  'camps',
#  'decency',
#  'threads',
#  'strategy',
#  'footsteps',
#  'tax',
#  'conceivable',
#  'Laboratory',
#  'sanction',
#  'began',
#  'Ruth',
#  'gin',
#  'script',
#  "Pont's",
#  'True',
#  'TSH',
#  'delegation',
#  'heavier',
#  'push',
#  'builders',
#  'friction',
#  'abstract',
#  'ideal',
#  'Philip',
#  'residence',
#  'purchasing',
#  'directions',
#  'orthodox',
#  'ballistic',
#  'speed',
#  'peasants',
#  'harvest',
#  'mixed',
#  'chances',
#  'traded',
#  'drainage',
#  'Cavalry',
#  'motel',
#  'bonds',
#  'whatever',
#  'reactivity',
#  'Cubism',
#  'go',
#  'chemistry',
#  'assembly',
#  'Water',
#  'strides',
#  'ethical',
#  'highly',
#  'cyclist',
#  'GOP',
#  'maps',
#  'Ray',
#  'towels',
#  'admire',
#  'Hillsboro',
#  'entirely',
#  'Olgivanna',
#  'remembering',
#  'luck',
#  'breadth',
#  'brings',
#  'sins',
#  'repaired',
#  'selecting',
#  'forgive',
#  'solids',
#  'partition',
#  'cage',
#  'saloons',
#  'quietly',
#  'conductor',
#  'maids',
#  'wonder',
#  'Drill',
#  'retrieved',
#  'leading',
#  'bacteria',
#  'Soviet',
#  'teach',
#  'anti-Semitism',
#  'steps',
#  'flexibility',
#  'spraying',
#  'p.',
#  'widespread',
#  'locating',
#  'Newark',
#  'hay',
#  'treating',
#  'winding',
#  'constructive',
#  'Barton',
#  'mist',
#  'sharing',
#  'Achievement',
#  'wondering',
#  'stored',
#  'decision',
#  'scores',
#  'cheeks',
#  'politics',
#  'Foreign',
#  'Methodist',
#  'polyether',
#  'borrowing',
#  'whole',
#  'constants',
#  'label',
#  'whites',
#  'bees',
#  'Hesperus',
#  'goals',
#  'cancel',
#  'fails',
#  'stove',
#  'financing',
#  'seats',
#  'relevant',
#  'agriculture',
#  "Plato's",
#  'Consider',
#  'February',
#  'augmented',
#  'ceiling',
#  'knee',
#  'lighted',
#  'words',
#  'questioned',
#  'boundaries',
#  'directional',
#  'Prairie',
#  'Harrington',
#  'theft',
#  'waiting',
#  'theaters',
#  'Tom',
#  'machinery',
#  'Seminary',
#  'superstition',
#  'plowing',
#  'cure',
#  'spacious',
#  'proceeded',
#  'thirty',
#  'Partlow',
#  'diagram',
#  'recipe',
#  'reach',
#  'accomplishment',
#  'traditional',
#  'pile',
#  'Columbus',
#  'Smith',
#  'provide',
#  'lousy',
#  'Bureau',
#  'spectrum',
#  'brown',
#  'influential',
#  'barn',
#  'popular',
#  'mouths',
#  'Zen',
#  'Looking',
#  'grant',
#  'easy',
#  'vacations',
#  'hazards',
#  'damp',
#  'Maria',
#  'mayor',
#  'bullet',
#  'Trevelyan',
#  "nation's",
#  'privileges',
#  'wagon',
#  'divine',
#  'course',
#  "America's",
#  'Birds',
#  'threaten',
#  "Government's",
#  'long-range',
#  'accessories',
#  "wife's",
#  'Beatrice',
#  'allowing',
#  'Graham',
#  'Depot',
#  'M.',
#  'World',
#  'pride',
#  'used',
#  'sources',
#  'promises',
#  'intersection',
#  'Back',
#  'Anderson',
#  'sister',
#  'transmission',
#  'Commission',
#  'discharge',
#  'us',
#  'installations',
#  'impulse',
#  'reply',
#  "woman's",
#  'academy',
#  'rubbing',
#  'alien',
#  'artist',
#  'elbows',
#  'observation',
#  'adoption',
#  'arbitrary',
#  'Friends',
#  'Todman',
#  'singing',
#  'Alabama',
#  'movements',
#  'pants',
#  'Opera',
#  'driveway',
#  'penetrating',
#  'cruelty',
#  'stared',
#  'study',
#  'grasp',
#  'overt',
#  'Buzz',
#  'immediately',
#  'scholarships',
#  'express',
#  'assumed',
#  'print',
#  'believes',
#  'legal',
#  'occurring',
#  'mutually',
#  'first',
#  'successful',
#  'watercolor',
#  'gum',
#  'forms',
#  'diplomacy',
#  'functioning',
#  'save',
#  'par',
#  'represented',
#  'mystery',
#  'Mass',
#  'studies',
#  'winning',
#  'Princeton',
#  'declaring',
#  'wool',
#  'Khrushchev',
#  'Connally',
#  'vaguely',
#  'chip',
#  'substances',
#  'simply',
#  'considerations',
#  '1000',
#  'Mays',
#  'remain',
#  'Pollock',
#  'Oliver',
#  'customer',
#  'correctly',
#  'missiles',
#  'established',
#  'Kent',
#  'current',
#  'politically',
#  '30',
#  'virtually',
#  'seventh',
#  'mortgage',
#  'looked',
#  'deduction',
#  'looks',
#  'identified',
#  'flames',
#  'marched',
#  'swelling',
#  'diseases',
#  'meal',
#  'Plato',
#  'Louis',
#  'evaluate',
#  'vitality',
#  'therefore',
#  'shades',
#  'compared',
#  'Corp.',
#  'concerts',
#  'bush',
#  'interim',
#  'indications',
#  'producer',
#  'coatings',
#  'vividly',
#  'already',
#  'acquisition',
#  'wanting',
#  'cutters',
#  'planners',
#  'ignored',
#  'petition',
#  'chooses',
#  'sensational',
#  'showing',
#  'deciding',
#  'victim',
#  'privately',
#  'receiver',
#  "Hudson's",
#  'calculation',
#  'whirling',
#  'muffled',
#  'Hirey',
#  'vacant',
#  'noted',
#  'V.',
#  'millions',
#  'programing',
#  'Bridget',
#  'trotted',
#  'merchants',
#  'guiding',
#  'realtors',
#  'feels',
#  'rent',
#  'simple',
#  'missed',
#  'quicker',
#  'everyday',
#  'private',
#  'Maryland',
#  'partially',
#  'Ever',
#  'contracts',
#  'guns',
#  'sounds',
#  'reserve',
#  'heated',
#  'somewhat',
#  "let's",
#  'safe',
#  'pin',
#  'related',
#  'favorably',
#  'bills',
#  'fired',
#  'conversion',
#  'Microscopically',
#  'yelled',
#  'staining',
#  'lots',
#  'measure',
#  'Future',
#  'Social',
#  'Shore',
#  'valley',
#  'readiness',
#  'designated',
#  'assignments',
#  'drain',
#  'intensifiers',
#  'poured',
#  'Shortly',
#  'estate',
#  'reactors',
#  'bird',
#  'smiling',
#  'fabric',
#  'perfect',
#  'antibody',
#  "Kennedy's",
#  'hostility',
#  'servants',
#  'witness',
#  'Usually',
#  'Handley',
#  'foundations',
#  'unprepared',
#  'searching',
#  'collective',
#  'drag',
#  'baptized',
#  '9',
#  'mourning',
#  'cumulative',
#  'westward',
#  'hard',
#  'repeatedly',
#  'Cathy',
#  'veranda',
#  'Take',
#  'stuck',
#  'shares',
#  'porous',
#  'curiosity',
#  'announced',
#  'talking',
#  'contained',
#  'meadow',
#  'nod',
#  'shelters',
#  'Foods',
#  'instituted',
#  'incorporated',
#  'educational',
#  'surprising',
#  'calcium',
#  'affirm',
#  'buses',
#  'clover',
#  'northern',
#  'photographs',
#  'Cardinal',
#  'inspiration',
#  'Form',
#  'price',
#  'exceptional',
#  'origins',
#  'disputes',
#  '7:30',
#  'grateful',
#  'electrons',
#  'among',
#  'Porter',
#  'Guam',
#  'greeted',
#  'true',
#  'procurement',
#  'sixth',
#  'Claire',
#  'Gray',
#  'Creator',
#  'eyelids',
#  'strict',
#  'cheerful',
#  'tail',
#  'Brooklyn',
#  'provides',
#  'supportive',
#  'affairs',
#  'cries',
#  'Thayer',
#  'authority',
#  'prosecution',
#  'Roy',
#  'person',
#  'controversial',
#  'aircraft',
#  'disastrous',
#  'recommendations',
#  'Hamrick',
#  'tremendous',
#  'Benson',
#  'obviously',
#  'eastern',
#  'Kohnstamm-negative',
#  'retained',
#  'scope',
#  'conclusive',
#  'machine',
#  'resort',
#  'Bobby',
#  'financial',
#  'becomes',
#  'exercise',
#  'answered',
#  'emergencies',
#  'sixty-five',
#  'offense',
#  'canvas',
#  'advisory',
#  'recall',
#  'analogous',
#  'prone',
#  'rabbit',
#  'habits',
#  'levers',
#  'ideological',
#  'accept',
#  'like',
#  'performances',
#  'pronounced',
#  'enormous',
#  'Appendix',
#  'receipts',
#  'hiding',
#  'breast',
#  'indefinite',
#  'player',
#  'shifts',
#  'queen',
#  'wings',
#  'angles',
#  'random',
#  'standpoint',
#  'Dulles',
#  'Thanks',
#  'enforce',
#  'tube',
#  'grimly',
#  'degree',
#  'edition',
#  'partly',
#  'difference',
#  'bundles',
#  'Discovery',
#  'fighter',
#  "child's",
#  'Holmes',
#  'remove',
#  'grow',
#  'cope',
#  'monument',
#  'thyroid',
#  'worthwhile',
#  'speak',
#  'honey',
#  'Jess',
#  'arguments',
#  'within',
#  'leader',
#  'genuinely',
#  'Great',
#  'Hong',
#  'strings',
#  'signing',
#  'director',
#  'outside',
#  'unpleasant',
#  'Revenue',
#  'ceramic',
#  'born',
#  'employment',
#  'size',
#  'B',
#  'Joan',
#  'generous',
#  'besides',
#  'enables',
#  'cut',
#  'span',
#  'Cousin',
#  'soils',
#  ...]

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'A.L.A.M.': 0, 'presumably': 1, 'Moon': 2, 'conferences': 3, 'leg': 4, 'denominations': 5, 'memory': 6, 'assistance': 7, 'two': 8, 'route': 9, 'sewage': 10, 'calculated': 11, 'revenge': 12, 'Authority': 13, 'four': 14, 'concepts': 15, 'dolls': 16, 'intentions': 17, 'flashes': 18, 'tsunami': 19, 'specimen': 20, 'Federation': 21, 'chin': 22, 'clinging': 23, 'oven': 24, 'mg/l': 25, 'overly': 26, 'eighteen': 27, 'eleven': 28, 'Others': 29, 'prevention': 30, 'compete': 31, 'passion': 32, 'integrate': 33, 'concerto': 34, 'cousin': 35, 'table': 36, 'parked': 37, 'supplies': 38, 'Today': 39, 'examining': 40, 'proclamation': 41, 'Wally': 42, 'dressing': 43, 'SBA': 44, 'evaluating': 45, 'references': 46, 'sampled': 47, 'wrinkles': 48, "Patchen's": 49, 'opportunity': 50, 'issued': 51, 'cutting': 52, 'wires': 53, 'hurry': 54, 'explosion': 55, 'bearing': 56, 'pockets': 57, 'Richardson': 58, 'illustrated': 59, 'Gardens': 60, 'recommending': 61, 'dubious': 62, 'forthcoming': 63, 'Kirby': 64, 'disease': 65, 'tourists': 66, 'realistically': 67, 'tense': 68, 'prices': 69, 'screens': 70, 'fostered': 71, 'poetry': 72, 'months': 73, 'novel': 74, 'aboard': 75, 'present': 76, 'bankers': 77, 'Frankie': 78, 'gravel': 79, 'Andrew': 80, 'forgotten': 81, 'Federal': 82, 'fairly': 83, 'fats': 84, 'adults': 85, 'excitedly': 86, 'Italians': 87, 'inescapable': 88, 'City': 89, 'growing': 90, 'necessity': 91, 'author': 92, 'arranged': 93, 'grinning': 94, 'Star': 95, 'Miriam': 96, 'consequence': 97, 'promoting': 98, 'equations': 99, 'Legislature': 100, 'wages': 101, 'Menshikov': 102, 'indignation': 103, 'Bishop': 104, 'ways': 105, 'limiting': 106, 'appearing': 107, 'natives': 108, 'X': 109, 'factories': 110, 'aerial': 111, 'struggled': 112, 'channels': 113, 'instruments': 114, 'brick': 115, '4': 116, "o'clock": 117, 'box': 118, 'Hampshire': 119, 'curious': 120, 'mixing': 121, 'choices': 122, 'pressure': 123, 'engagements': 124, 'Stadium': 125, 'earthy': 126, 'ambiguity': 127, 'Eastern': 128, 'accurate': 129, 'wave': 130, 'cottage': 131, 'comfortably': 132, 'Atlantic': 133, 'Jimmy': 134, 'recruit': 135, 'heartily': 136, 'coffee': 137, 'relationships': 138, 'absorbed': 139, 'lend': 140, 'grain': 141, 'feed': 142, 'cards': 143, 'nitrogen': 144, 'cargo': 145, 'negotiating': 146, 'carpenter': 147, 'Organization': 148, 'defeat': 149, 'dictatorship': 150, 'Ave.': 151, 'theme': 152, 'squeezed': 153, 'nomination': 154, 'proposing': 155, 'detached': 156, 'suggesting': 157, 'Nassau': 158, 'benefit': 159, 'lawyer': 160, 'style': 161, 'Lincoln': 162, 'phosphor': 163, 'inference': 164, 'converted': 165, 'selections': 166, 'rate': 167, 'spinning': 168, 'novels': 169, 'honesty': 170, 'teachers': 171, 'free': 172, 'Meanwhile': 173, 'Still': 174, 'Edward': 175, 'returned': 176, 'boards': 177, 'ambulance': 178, 'flew': 179, 'learn': 180, 'Also': 181, 'supernatural': 182, 'bond': 183, 'ancestry': 184, 'appreciated': 185, 'center': 186, 'Southerners': 187, 'consists': 188, 'incentive': 189, 'show': 190, 'flesh': 191, 'trick': 192, 'assign': 193, 'decreased': 194, 'irradiation': 195, 'chairs': 196, 'boost': 197, 'assumes': 198, 'Robert': 199, 'packing': 200, 'lines': 201, 'orbit': 202, "State's": 203, 'votes': 204, 'photographic': 205, 'attorney': 206, 'micrometeorite': 207, 'Would': 208, 'expert': 209, 'tactics': 210, 'clergyman': 211, 'limit': 212, 'explicit': 213, 'bronze': 214, 'Hotel': 215, 'glorious': 216, 'scraped': 217, 'relief': 218, 'wore': 219, 'acquainted': 220, 'straightforward': 221, 'Maude': 222, 'faces': 223, 'succession': 224, 'probably': 225, 'Dec.': 226, 'energetic': 227, 'benefits': 228, 'Sons': 229, '110': 230, 'prevented': 231, 'doubling': 232, 'ninety': 233, 'sooner': 234, 'shattered': 235, 'replacement': 236, 'divorce': 237, 'external': 238, 'burn': 239, 'characterized': 240, 'biography': 241, 'Bridge': 242, 'accustomed': 243, 'fulfill': 244, 'handicap': 245, 'Swift': 246, 'ripped': 247, 'tender': 248, '1930': 249, 'necessary': 250, 'electricity': 251, 'writi ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 10582

# %%
#append UNK
vocab.append('<UNK>')

# %%
vocab
# Out:
# ['A.L.A.M.',
#  'presumably',
#  'Moon',
#  'conferences',
#  'leg',
#  'denominations',
#  'memory',
#  'assistance',
#  'two',
#  'route',
#  'sewage',
#  'calculated',
#  'revenge',
#  'Authority',
#  'four',
#  'concepts',
#  'dolls',
#  'intentions',
#  'flashes',
#  'tsunami',
#  'specimen',
#  'Federation',
#  'chin',
#  'clinging',
#  'oven',
#  'mg/l',
#  'overly',
#  'eighteen',
#  'eleven',
#  'Others',
#  'prevention',
#  'compete',
#  'passion',
#  'integrate',
#  'concerto',
#  'cousin',
#  'table',
#  'parked',
#  'supplies',
#  'Today',
#  'examining',
#  'proclamation',
#  'Wally',
#  'dressing',
#  'SBA',
#  'evaluating',
#  'references',
#  'sampled',
#  'wrinkles',
#  "Patchen's",
#  'opportunity',
#  'issued',
#  'cutting',
#  'wires',
#  'hurry',
#  'explosion',
#  'bearing',
#  'pockets',
#  'Richardson',
#  'illustrated',
#  'Gardens',
#  'recommending',
#  'dubious',
#  'forthcoming',
#  'Kirby',
#  'disease',
#  'tourists',
#  'realistically',
#  'tense',
#  'prices',
#  'screens',
#  'fostered',
#  'poetry',
#  'months',
#  'novel',
#  'aboard',
#  'present',
#  'bankers',
#  'Frankie',
#  'gravel',
#  'Andrew',
#  'forgotten',
#  'Federal',
#  'fairly',
#  'fats',
#  'adults',
#  'excitedly',
#  'Italians',
#  'inescapable',
#  'City',
#  'growing',
#  'necessity',
#  'author',
#  'arranged',
#  'grinning',
#  'Star',
#  'Miriam',
#  'consequence',
#  'promoting',
#  'equations',
#  'Legislature',
#  'wages',
#  'Menshikov',
#  'indignation',
#  'Bishop',
#  'ways',
#  'limiting',
#  'appearing',
#  'natives',
#  'X',
#  'factories',
#  'aerial',
#  'struggled',
#  'channels',
#  'instruments',
#  'brick',
#  '4',
#  "o'clock",
#  'box',
#  'Hampshire',
#  'curious',
#  'mixing',
#  'choices',
#  'pressure',
#  'engagements',
#  'Stadium',
#  'earthy',
#  'ambiguity',
#  'Eastern',
#  'accurate',
#  'wave',
#  'cottage',
#  'comfortably',
#  'Atlantic',
#  'Jimmy',
#  'recruit',
#  'heartily',
#  'coffee',
#  'relationships',
#  'absorbed',
#  'lend',
#  'grain',
#  'feed',
#  'cards',
#  'nitrogen',
#  'cargo',
#  'negotiating',
#  'carpenter',
#  'Organization',
#  'defeat',
#  'dictatorship',
#  'Ave.',
#  'theme',
#  'squeezed',
#  'nomination',
#  'proposing',
#  'detached',
#  'suggesting',
#  'Nassau',
#  'benefit',
#  'lawyer',
#  'style',
#  'Lincoln',
#  'phosphor',
#  'inference',
#  'converted',
#  'selections',
#  'rate',
#  'spinning',
#  'novels',
#  'honesty',
#  'teachers',
#  'free',
#  'Meanwhile',
#  'Still',
#  'Edward',
#  'returned',
#  'boards',
#  'ambulance',
#  'flew',
#  'learn',
#  'Also',
#  'supernatural',
#  'bond',
#  'ancestry',
#  'appreciated',
#  'center',
#  'Southerners',
#  'consists',
#  'incentive',
#  'show',
#  'flesh',
#  'trick',
#  'assign',
#  'decreased',
#  'irradiation',
#  'chairs',
#  'boost',
#  'assumes',
#  'Robert',
#  'packing',
#  'lines',
#  'orbit',
#  "State's",
#  'votes',
#  'photographic',
#  'attorney',
#  'micrometeorite',
#  'Would',
#  'expert',
#  'tactics',
#  'clergyman',
#  'limit',
#  'explicit',
#  'bronze',
#  'Hotel',
#  'glorious',
#  'scraped',
#  'relief',
#  'wore',
#  'acquainted',
#  'straightforward',
#  'Maude',
#  'faces',
#  'succession',
#  'probably',
#  'Dec.',
#  'energetic',
#  'benefits',
#  'Sons',
#  '110',
#  'prevented',
#  'doubling',
#  'ninety',
#  'sooner',
#  'shattered',
#  'replacement',
#  'divorce',
#  'external',
#  'burn',
#  'characterized',
#  'biography',
#  'Bridge',
#  'accustomed',
#  'fulfill',
#  'handicap',
#  'Swift',
#  'ripped',
#  'tender',
#  '1930',
#  'necessary',
#  'electricity',
#  'writing',
#  'passages',
#  'stirring',
#  'anecdote',
#  'irregular',
#  "Papa's",
#  'achieving',
#  'intelligible',
#  'combines',
#  'illumination',
#  'components',
#  'call',
#  'hotels',
#  'stamp',
#  'Lester',
#  'mathematics',
#  'Next',
#  'applicable',
#  'conclusion',
#  'lore',
#  'column',
#  'hear',
#  'Victor',
#  'intuition',
#  'negative',
#  'plane',
#  'brother',
#  'Wisconsin',
#  'callous',
#  'war',
#  'operand',
#  'periods',
#  'modify',
#  'initiative',
#  'shaken',
#  'picket',
#  'seen',
#  'Crombie',
#  'neglected',
#  'manners',
#  'token',
#  'lightning',
#  'compulsive',
#  'forests',
#  'findings',
#  'cylinders',
#  'Deegan',
#  'Kodyke',
#  'guarantees',
#  'Pulley',
#  'corporations',
#  'Jew',
#  'juice',
#  'narrowed',
#  'colorful',
#  'rice',
#  'exposure',
#  'birthday',
#  'vitamins',
#  'deduced',
#  'inquiries',
#  'wounded',
#  'educated',
#  'respectable',
#  'comprehensive',
#  'dropping',
#  'nature',
#  'particularly',
#  "Mann's",
#  'visitor',
#  'banks',
#  'Times',
#  'lap',
#  'killed',
#  'performing',
#  'repeating',
#  'Eden',
#  'ambassador',
#  'strewn',
#  'glanced',
#  'military',
#  'red',
#  'Nevertheless',
#  'document',
#  'Af',
#  'Lalaurie',
#  'Madden',
#  'ironic',
#  'Stone',
#  'key',
#  'disarmament',
#  'psychologists',
#  'haste',
#  'strikes',
#  'magnetism',
#  'hollow',
#  'T.',
#  'founding',
#  'bow',
#  'chromatic',
#  'Eve',
#  'revolutionary',
#  'sights',
#  'entered',
#  'taut',
#  'Sandburg',
#  'warnings',
#  'hats',
#  'presentations',
#  'contains',
#  'enemies',
#  'Anthony',
#  'relationship',
#  'continuity',
#  'generators',
#  'Englishmen',
#  'strand',
#  'pack',
#  'utilizing',
#  "poet's",
#  'transformation',
#  'tasted',
#  'arguing',
#  'Union',
#  'however',
#  'Angie',
#  'Van',
#  'vertical',
#  '1,000',
#  'thermometer',
#  'hair',
#  '0.5',
#  'characterization',
#  'couples',
#  'greatness',
#  'elimination',
#  'turned',
#  'stopped',
#  'Pohl',
#  'Boys',
#  'players',
#  'settled',
#  'contributing',
#  'approval',
#  'apparent',
#  'tells',
#  "B'dikkat",
#  'Chester',
#  'exhibited',
#  '17th',
#  'comprise',
#  'Madame',
#  'Square',
#  'essential',
#  'discrimination',
#  'whiskey',
#  'Dallas',
#  'Ada',
#  'chairmen',
#  'wishes',
#  'evaluation',
#  'received',
#  'judged',
#  'actually',
#  'campus',
#  'responded',
#  'sensitivity',
#  'House',
#  'power',
#  'seventeen',
#  'Bank',
#  'increasing',
#  'December',
#  'Expressway',
#  '24',
#  "car's",
#  'inserted',
#  'mothers',
#  'sentenced',
#  'Local',
#  'shipping',
#  'glancing',
#  'incredible',
#  'equitable',
#  'pill',
#  'notice',
#  'needs',
#  'slept',
#  'E.',
#  'frail',
#  'reasons',
#  'Katie',
#  'pointed',
#  'polarization',
#  'addressing',
#  'camps',
#  'decency',
#  'threads',
#  'strategy',
#  'footsteps',
#  'tax',
#  'conceivable',
#  'Laboratory',
#  'sanction',
#  'began',
#  'Ruth',
#  'gin',
#  'script',
#  "Pont's",
#  'True',
#  'TSH',
#  'delegation',
#  'heavier',
#  'push',
#  'builders',
#  'friction',
#  'abstract',
#  'ideal',
#  'Philip',
#  'residence',
#  'purchasing',
#  'directions',
#  'orthodox',
#  'ballistic',
#  'speed',
#  'peasants',
#  'harvest',
#  'mixed',
#  'chances',
#  'traded',
#  'drainage',
#  'Cavalry',
#  'motel',
#  'bonds',
#  'whatever',
#  'reactivity',
#  'Cubism',
#  'go',
#  'chemistry',
#  'assembly',
#  'Water',
#  'strides',
#  'ethical',
#  'highly',
#  'cyclist',
#  'GOP',
#  'maps',
#  'Ray',
#  'towels',
#  'admire',
#  'Hillsboro',
#  'entirely',
#  'Olgivanna',
#  'remembering',
#  'luck',
#  'breadth',
#  'brings',
#  'sins',
#  'repaired',
#  'selecting',
#  'forgive',
#  'solids',
#  'partition',
#  'cage',
#  'saloons',
#  'quietly',
#  'conductor',
#  'maids',
#  'wonder',
#  'Drill',
#  'retrieved',
#  'leading',
#  'bacteria',
#  'Soviet',
#  'teach',
#  'anti-Semitism',
#  'steps',
#  'flexibility',
#  'spraying',
#  'p.',
#  'widespread',
#  'locating',
#  'Newark',
#  'hay',
#  'treating',
#  'winding',
#  'constructive',
#  'Barton',
#  'mist',
#  'sharing',
#  'Achievement',
#  'wondering',
#  'stored',
#  'decision',
#  'scores',
#  'cheeks',
#  'politics',
#  'Foreign',
#  'Methodist',
#  'polyether',
#  'borrowing',
#  'whole',
#  'constants',
#  'label',
#  'whites',
#  'bees',
#  'Hesperus',
#  'goals',
#  'cancel',
#  'fails',
#  'stove',
#  'financing',
#  'seats',
#  'relevant',
#  'agriculture',
#  "Plato's",
#  'Consider',
#  'February',
#  'augmented',
#  'ceiling',
#  'knee',
#  'lighted',
#  'words',
#  'questioned',
#  'boundaries',
#  'directional',
#  'Prairie',
#  'Harrington',
#  'theft',
#  'waiting',
#  'theaters',
#  'Tom',
#  'machinery',
#  'Seminary',
#  'superstition',
#  'plowing',
#  'cure',
#  'spacious',
#  'proceeded',
#  'thirty',
#  'Partlow',
#  'diagram',
#  'recipe',
#  'reach',
#  'accomplishment',
#  'traditional',
#  'pile',
#  'Columbus',
#  'Smith',
#  'provide',
#  'lousy',
#  'Bureau',
#  'spectrum',
#  'brown',
#  'influential',
#  'barn',
#  'popular',
#  'mouths',
#  'Zen',
#  'Looking',
#  'grant',
#  'easy',
#  'vacations',
#  'hazards',
#  'damp',
#  'Maria',
#  'mayor',
#  'bullet',
#  'Trevelyan',
#  "nation's",
#  'privileges',
#  'wagon',
#  'divine',
#  'course',
#  "America's",
#  'Birds',
#  'threaten',
#  "Government's",
#  'long-range',
#  'accessories',
#  "wife's",
#  'Beatrice',
#  'allowing',
#  'Graham',
#  'Depot',
#  'M.',
#  'World',
#  'pride',
#  'used',
#  'sources',
#  'promises',
#  'intersection',
#  'Back',
#  'Anderson',
#  'sister',
#  'transmission',
#  'Commission',
#  'discharge',
#  'us',
#  'installations',
#  'impulse',
#  'reply',
#  "woman's",
#  'academy',
#  'rubbing',
#  'alien',
#  'artist',
#  'elbows',
#  'observation',
#  'adoption',
#  'arbitrary',
#  'Friends',
#  'Todman',
#  'singing',
#  'Alabama',
#  'movements',
#  'pants',
#  'Opera',
#  'driveway',
#  'penetrating',
#  'cruelty',
#  'stared',
#  'study',
#  'grasp',
#  'overt',
#  'Buzz',
#  'immediately',
#  'scholarships',
#  'express',
#  'assumed',
#  'print',
#  'believes',
#  'legal',
#  'occurring',
#  'mutually',
#  'first',
#  'successful',
#  'watercolor',
#  'gum',
#  'forms',
#  'diplomacy',
#  'functioning',
#  'save',
#  'par',
#  'represented',
#  'mystery',
#  'Mass',
#  'studies',
#  'winning',
#  'Princeton',
#  'declaring',
#  'wool',
#  'Khrushchev',
#  'Connally',
#  'vaguely',
#  'chip',
#  'substances',
#  'simply',
#  'considerations',
#  '1000',
#  'Mays',
#  'remain',
#  'Pollock',
#  'Oliver',
#  'customer',
#  'correctly',
#  'missiles',
#  'established',
#  'Kent',
#  'current',
#  'politically',
#  '30',
#  'virtually',
#  'seventh',
#  'mortgage',
#  'looked',
#  'deduction',
#  'looks',
#  'identified',
#  'flames',
#  'marched',
#  'swelling',
#  'diseases',
#  'meal',
#  'Plato',
#  'Louis',
#  'evaluate',
#  'vitality',
#  'therefore',
#  'shades',
#  'compared',
#  'Corp.',
#  'concerts',
#  'bush',
#  'interim',
#  'indications',
#  'producer',
#  'coatings',
#  'vividly',
#  'already',
#  'acquisition',
#  'wanting',
#  'cutters',
#  'planners',
#  'ignored',
#  'petition',
#  'chooses',
#  'sensational',
#  'showing',
#  'deciding',
#  'victim',
#  'privately',
#  'receiver',
#  "Hudson's",
#  'calculation',
#  'whirling',
#  'muffled',
#  'Hirey',
#  'vacant',
#  'noted',
#  'V.',
#  'millions',
#  'programing',
#  'Bridget',
#  'trotted',
#  'merchants',
#  'guiding',
#  'realtors',
#  'feels',
#  'rent',
#  'simple',
#  'missed',
#  'quicker',
#  'everyday',
#  'private',
#  'Maryland',
#  'partially',
#  'Ever',
#  'contracts',
#  'guns',
#  'sounds',
#  'reserve',
#  'heated',
#  'somewhat',
#  "let's",
#  'safe',
#  'pin',
#  'related',
#  'favorably',
#  'bills',
#  'fired',
#  'conversion',
#  'Microscopically',
#  'yelled',
#  'staining',
#  'lots',
#  'measure',
#  'Future',
#  'Social',
#  'Shore',
#  'valley',
#  'readiness',
#  'designated',
#  'assignments',
#  'drain',
#  'intensifiers',
#  'poured',
#  'Shortly',
#  'estate',
#  'reactors',
#  'bird',
#  'smiling',
#  'fabric',
#  'perfect',
#  'antibody',
#  "Kennedy's",
#  'hostility',
#  'servants',
#  'witness',
#  'Usually',
#  'Handley',
#  'foundations',
#  'unprepared',
#  'searching',
#  'collective',
#  'drag',
#  'baptized',
#  '9',
#  'mourning',
#  'cumulative',
#  'westward',
#  'hard',
#  'repeatedly',
#  'Cathy',
#  'veranda',
#  'Take',
#  'stuck',
#  'shares',
#  'porous',
#  'curiosity',
#  'announced',
#  'talking',
#  'contained',
#  'meadow',
#  'nod',
#  'shelters',
#  'Foods',
#  'instituted',
#  'incorporated',
#  'educational',
#  'surprising',
#  'calcium',
#  'affirm',
#  'buses',
#  'clover',
#  'northern',
#  'photographs',
#  'Cardinal',
#  'inspiration',
#  'Form',
#  'price',
#  'exceptional',
#  'origins',
#  'disputes',
#  '7:30',
#  'grateful',
#  'electrons',
#  'among',
#  'Porter',
#  'Guam',
#  'greeted',
#  'true',
#  'procurement',
#  'sixth',
#  'Claire',
#  'Gray',
#  'Creator',
#  'eyelids',
#  'strict',
#  'cheerful',
#  'tail',
#  'Brooklyn',
#  'provides',
#  'supportive',
#  'affairs',
#  'cries',
#  'Thayer',
#  'authority',
#  'prosecution',
#  'Roy',
#  'person',
#  'controversial',
#  'aircraft',
#  'disastrous',
#  'recommendations',
#  'Hamrick',
#  'tremendous',
#  'Benson',
#  'obviously',
#  'eastern',
#  'Kohnstamm-negative',
#  'retained',
#  'scope',
#  'conclusive',
#  'machine',
#  'resort',
#  'Bobby',
#  'financial',
#  'becomes',
#  'exercise',
#  'answered',
#  'emergencies',
#  'sixty-five',
#  'offense',
#  'canvas',
#  'advisory',
#  'recall',
#  'analogous',
#  'prone',
#  'rabbit',
#  'habits',
#  'levers',
#  'ideological',
#  'accept',
#  'like',
#  'performances',
#  'pronounced',
#  'enormous',
#  'Appendix',
#  'receipts',
#  'hiding',
#  'breast',
#  'indefinite',
#  'player',
#  'shifts',
#  'queen',
#  'wings',
#  'angles',
#  'random',
#  'standpoint',
#  'Dulles',
#  'Thanks',
#  'enforce',
#  'tube',
#  'grimly',
#  'degree',
#  'edition',
#  'partly',
#  'difference',
#  'bundles',
#  'Discovery',
#  'fighter',
#  "child's",
#  'Holmes',
#  'remove',
#  'grow',
#  'cope',
#  'monument',
#  'thyroid',
#  'worthwhile',
#  'speak',
#  'honey',
#  'Jess',
#  'arguments',
#  'within',
#  'leader',
#  'genuinely',
#  'Great',
#  'Hong',
#  'strings',
#  'signing',
#  'director',
#  'outside',
#  'unpleasant',
#  'Revenue',
#  'ceramic',
#  'born',
#  'employment',
#  'size',
#  'B',
#  'Joan',
#  'generous',
#  'besides',
#  'enables',
#  'cut',
#  'span',
#  'Cousin',
#  'soils',
#  ...]

# %%
word2index['<UNK>'] = 0

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
X_i = Counter(flatten(corpus))
X_i
# Out:
# Counter({"''": 5807,
#          '``': 5800,
#          '--': 2321,
#          'one': 2235,
#          'would': 2059,
#          'said': 1593,
#          'could': 1213,
#          'time': 1211,
#          'two': 1036,
#          'may': 1000,
#          'like': 967,
#          'first': 964,
#          'man': 909,
#          'made': 846,
#          'new': 816,
#          'also': 810,
#          'must': 799,
#          'Af': 793,
#          'back': 785,
#          'years': 747,
#          'even': 734,
#          'many': 717,
#          'much': 701,
#          'way': 680,
#          'little': 661,
#          'Mr.': 645,
#          'people': 632,
#          'make': 620,
#          'good': 608,
#          'work': 589,
#          'well': 576,
#          'see': 574,
#          'get': 573,
#          'still': 573,
#          'men': 555,
#          'long': 548,
#          'us': 528,
#          'world': 515,
#          'might': 514,
#          'life': 504,
#          'never': 501,
#          'used': 495,
#          'came': 494,
#          'year': 487,
#          'last': 487,
#          'know': 481,
#          'day': 471,
#          'go': 470,
#          'great': 466,
#          'around': 458,
#          'another': 456,
#          'take': 454,
#          'come': 440,
#          'old': 434,
#          'use': 432,
#          'three': 430,
#          'right': 426,
#          'state': 420,
#          'without': 420,
#          'American': 418,
#          'found': 417,
#          'place': 415,
#          'home': 411,
#          'small': 411,
#          'New': 403,
#          'went': 401,
#          'say': 391,
#          'thought': 390,
#          'left': 388,
#          'Mrs.': 372,
#          'away': 372,
#          'got': 365,
#          'high': 360,
#          'every': 350,
#          'number': 349,
#          'since': 349,
#          'part': 349,
#          'One': 348,
#          'always': 346,
#          'course': 344,
#          'water': 343,
#          'fact': 342,
#          'less': 336,
#          'something': 335,
#          'took': 333,
#          'enough': 331,
#          'school': 329,
#          'hand': 329,
#          'put': 328,
#          'house': 327,
#          'upon': 325,
#          '1': 319,
#          'think': 319,
#          'head': 318,
#          'almost': 318,
#          'side': 318,
#          'system': 317,
#          'find': 312,
#          'however': 312,
#          'better': 312,
#          'told': 311,
#          'far': 311,
#          'night': 310,
#          'eyes': 309,
#          'end': 307,
#          'knew': 306,
#          'called': 305,
#          'toward': 304,
#          'days': 304,
#          'point': 301,
#          'give': 300,
#          'face': 299,
#          'become': 299,
#          'going': 298,
#          'set': 296,
#          'group': 296,
#          'next': 294,
#          'felt': 294,
#          'given': 292,
#          'public': 289,
#          'program': 288,
#          'possible': 288,
#          'often': 287,
#          'present': 285,
#          'though': 285,
#          'important': 283,
#          'form': 282,
#          'look': 282,
#          'room': 280,
#          'saw': 278,
#          'young': 278,
#          'later': 277,
#          'social': 277,
#          'things': 277,
#          'second': 277,
#          'area': 275,
#          'United': 271,
#          'large': 269,
#          'business': 269,
#          'per': 267,
#          'along': 266,
#          'nothing': 266,
#          'case': 265,
#          'door': 265,
#          'least': 264,
#          'children': 264,
#          'order': 263,
#          'need': 262,
#          'thing': 262,
#          'seemed': 261,
#          'rather': 260,
#          'several': 259,
#          'States': 258,
#          'done': 257,
#          'problem': 256,
#          'ever': 256,
#          'looked': 255,
#          'mind': 253,
#          'big': 251,
#          'within': 250,
#          'four': 249,
#          'country': 249,
#          'want': 248,
#          'turned': 248,
#          'light': 248,
#          'early': 246,
#          'best': 246,
#          'power': 245,
#          'sense': 243,
#          'began': 243,
#          'open': 242,
#          'members': 241,
#          'interest': 240,
#          'family': 240,
#          'feet': 240,
#          'matter': 238,
#          '2': 237,
#          'general': 237,
#          'kind': 237,
#          'among': 237,
#          'help': 236,
#          'whole': 233,
#          'John': 233,
#          'different': 233,
#          'certain': 232,
#          'asked': 230,
#          'experience': 229,
#          'let': 228,
#          'development': 225,
#          'across': 222,
#          'seen': 221,
#          'others': 220,
#          'gave': 220,
#          'war': 220,
#          'taken': 216,
#          'keep': 216,
#          'York': 216,
#          'God': 216,
#          'quite': 216,
#          'past': 215,
#          'history': 215,
#          'means': 213,
#          'information': 213,
#          'either': 213,
#          'body': 212,
#          'example': 210,
#          'human': 210,
#          'half': 209,
#          'yet': 208,
#          'death': 208,
#          'line': 208,
#          'law': 207,
#          'local': 207,
#          'cannot': 207,
#          'brought': 206,
#          'money': 205,
#          'behind': 205,
#          'show': 205,
#          'really': 205,
#          'car': 205,
#          'name': 204,
#          'period': 204,
#          'moment': 204,
#          "I'm": 203,
#          'action': 202,
#          'field': 202,
#          'words': 202,
#          'city': 201,
#          'making': 199,
#          'hands': 199,
#          'held': 198,
#          'times': 198,
#          'together': 197,
#          'five': 197,
#          'ago': 197,
#          'anything': 197,
#          'seems': 196,
#          'word': 195,
#          'week': 195,
#          'government': 195,
#          'white': 195,
#          'President': 194,
#          'became': 193,
#          'political': 192,
#          'problems': 191,
#          'change': 188,
#          'job': 188,
#          'already': 188,
#          'boy': 188,
#          'result': 187,
#          'study': 187,
#          'areas': 187,
#          'real': 187,
#          'close': 187,
#          'known': 187,
#          'wanted': 186,
#          'available': 185,
#          'tell': 185,
#          'position': 185,
#          'company': 185,
#          'sure': 185,
#          'whether': 184,
#          'probably': 184,
#          'question': 184,
#          'free': 183,
#          'major': 183,
#          'reason': 183,
#          'wife': 182,
#          'today': 182,
#          'necessary': 182,
#          'State': 181,
#          'heard': 181,
#          'individual': 180,
#          'front': 178,
#          'child': 176,
#          'community': 174,
#          'woman': 174,
#          'stood': 173,
#          'full': 173,
#          'seem': 173,
#          'able': 171,
#          'turn': 171,
#          'special': 170,
#          'town': 170,
#          'office': 169,
#          'top': 169,
#          'voice': 169,
#          'run': 168,
#          'air': 168,
#          'Miss': 168,
#          'feel': 167,
#          'control': 167,
#          'service': 166,
#          'clear': 166,
#          'church': 166,
#          'provide': 165,
#          'age': 165,
#          'evidence': 164,
#          'level': 164,
#          'started': 164,
#          'short': 164,
#          '3': 163,
#          'usually': 163,
#          'perhaps': 163,
#          'type': 162,
#          'value': 162,
#          'policy': 161,
#          'effect': 160,
#          'needed': 159,
#          'common': 159,
#          'girl': 159,
#          'whose': 158,
#          'surface': 158,
#          'national': 157,
#          'cost': 156,
#          'plan': 156,
#          'Even': 156,
#          'play': 156,
#          'future': 155,
#          'believe': 155,
#          'living': 155,
#          'outside': 155,
#          'love': 155,
#          'strong': 154,
#          'morning': 154,
#          'students': 153,
#          'situation': 153,
#          'sound': 152,
#          'land': 152,
#          'leave': 152,
#          'six': 151,
#          'party': 150,
#          'hard': 150,
#          'true': 150,
#          'process': 150,
#          'music': 150,
#          'near': 149,
#          'mean': 149,
#          'months': 149,
#          'ground': 149,
#          'society': 149,
#          'following': 148,
#          'minutes': 148,
#          'force': 147,
#          'Washington': 147,
#          'various': 147,
#          'modern': 146,
#          'art': 146,
#          'values': 146,
#          'added': 145,
#          'Since': 145,
#          'moved': 145,
#          'longer': 145,
#          'million': 144,
#          'schools': 144,
#          'tax': 144,
#          'cut': 144,
#          'economic': 144,
#          'space': 144,
#          'says': 143,
#          'personal': 143,
#          'required': 143,
#          'nature': 143,
#          'total': 143,
#          'However': 142,
#          'expected': 142,
#          'road': 142,
#          'lines': 142,
#          'view': 142,
#          'center': 142,
#          'century': 142,
#          'mother': 142,
#          'greater': 141,
#          'soon': 141,
#          'although': 141,
#          'idea': 141,
#          'alone': 141,
#          'private': 141,
#          'attention': 141,
#          'English': 140,
#          'shown': 140,
#          'fire': 139,
#          'Dr.': 139,
#          'pressure': 139,
#          'support': 139,
#          'basis': 139,
#          'stage': 139,
#          'Thus': 139,
#          'House': 138,
#          'kept': 138,
#          'hours': 138,
#          'complete': 138,
#          'women': 138,
#          'increase': 137,
#          'return': 137,
#          'West': 137,
#          'America': 137,
#          'particular': 137,
#          'dark': 137,
#          'coming': 136,
#          'military': 136,
#          'gone': 136,
#          'rate': 135,
#          'shall': 135,
#          "I'll": 135,
#          'except': 134,
#          'reached': 134,
#          'makes': 134,
#          'material': 134,
#          'feeling': 133,
#          'live': 132,
#          'taking': 132,
#          'lost': 132,
#          'floor': 132,
#          'inside': 132,
#          'difficult': 132,
#          'conditions': 132,
#          'single': 132,
#          'trying': 132,
#          'black': 132,
#          'equipment': 132,
#          'third': 130,
#          'person': 130,
#          'heart': 130,
#          'looking': 130,
#          'picture': 130,
#          'tried': 130,
#          'father': 130,
#          'followed': 129,
#          'book': 129,
#          'spirit': 129,
#          'sometimes': 129,
#          'hope': 128,
#          'late': 128,
#          'class': 128,
#          'education': 127,
#          'else': 127,
#          'beyond': 127,
#          'miles': 127,
#          'terms': 127,
#          'board': 126,
#          'dead': 126,
#          'ten': 126,
#          'read': 125,
#          'South': 125,
#          'move': 125,
#          'everything': 125,
#          '1960': 125,
#          'received': 124,
#          'hold': 124,
#          'passed': 124,
#          'call': 124,
#          'paper': 124,
#          'bring': 124,
#          'walked': 124,
#          'developed': 123,
#          'industry': 123,
#          'simply': 123,
#          'pay': 122,
#          'hear': 122,
#          'needs': 122,
#          'effort': 122,
#          'wrote': 122,
#          'rest': 122,
#          'sat': 122,
#          'religious': 121,
#          'sort': 121,
#          'figure': 121,
#          'wall': 121,
#          'therefore': 121,
#          'natural': 121,
#          'similar': 120,
#          '4': 120,
#          'General': 120,
#          'beginning': 120,
#          'points': 120,
#          'act': 119,
#          'getting': 119,
#          'college': 119,
#          'states': 119,
#          'considered': 119,
#          'street': 119,
#          'data': 119,
#          'recent': 118,
#          'size': 118,
#          'Department': 118,
#          'meeting': 118,
#          'addition': 118,
#          "can't": 118,
#          'amount': 118,
#          'hundred': 118,
#          'hair': 118,
#          'building': 117,
#          'training': 117,
#          'low': 117,
#          'range': 117,
#          'purpose': 116,
#          'subject': 116,
#          'weeks': 116,
#          'growth': 116,
#          'showed': 116,
#          'final': 115,
#          'care': 115,
#          'higher': 115,
#          'forces': 115,
#          'especially': 115,
#          'ready': 114,
#          'stand': 114,
#          'table': 114,
#          'letter': 114,
#          'England': 114,
#          'sent': 113,
#          'written': 113,
#          'likely': 112,
#          'U.S.': 112,
#          'normal': 112,
#          'basic': 112,
#          'population': 112,
#          'National': 112,
#          'entire': 112,
#          'North': 112,
#          'piece': 112,
#          'cold': 112,
#          'cent': 111,
#          'opened': 111,
#          'hour': 111,
#          'working': 111,
#          'comes': 111,
#          'story': 111,
#          'moral': 111,
#          'costs': 110,
#          'report': 110,
#          'countries': 110,
#          'bad': 110,
#          'simple': 110,
#          'Yet': 110,
#          'fine': 109,
#          'decided': 109,
#          'particularly': 109,
#          'talk': 109,
#          'thus': 109,
#          'St.': 109,
#          'thinking': 109,
#          'son': 108,
#          'property': 108,
#          'color': 108,
#          'Kennedy': 108,
#          'knowledge': 108,
#          'concerned': 108,
#          'direction': 108,
#          'difference': 108,
#          'carried': 108,
#          'strength': 108,
#          'lay': 108,
#          'earlier': 107,
#          'cases': 107,
#          'paid': 107,
#          'friends': 107,
#          'ran': 107,
#          "I've": 107,
#          'food': 107,
#          'Christian': 107,
#          'French': 107,
#          'production': 107,
#          'issue': 106,
#          'questions': 106,
#          'police': 106,
#          'involved': 106,
#          'meet': 106,
#          'fall': 106,
#          'understand': 106,
#          'lot': 106,
#          'forms': 106,
#          'finally': 105,
#          'statement': 105,
#          'systems': 105,
#          'trade': 105,
#          'member': 105,
#          'method': 105,
#          'start': 105,
#          'bed': 105,
#          'husband': 105,
#          'methods': 104,
#          'defense': 104,
#          'anyone': 104,
#          'results': 104,
#          'War': 104,
#          'literature': 104,
#          'summer': 103,
#          'ideas': 103,
#          'directly': 103,
#          'appeared': 103,
#          'happened': 103,
#          'physical': 103,
#          'red': 103,
#          'City': 102,
#          'William': 102,
#          'including': 102,
#          '10': 102,
#          'reading': 102,
#          'programs': 102,
#          'record': 102,
#          'step': 102,
#          'East': 102,
#          'eye': 102,
#          'placed': 102,
#          'plant': 102,
#          'month': 102,
#          'suddenly': 102,
#          'theory': 102,
#          'Aj': 101,
#          'trouble': 101,
#          'performance': 101,
#          'window': 101,
#          'steps': 100,
#          'worked': 100,
#          'groups': 100,
#          'try': 100,
#          'continued': 100,
#          'deal': 99,
#          'obtained': 99,
#          'Soviet': 99,
#          'stopped': 99,
#          'peace': 99,
#          'market': 99,
#          'friend': 99,
#          'girls': 99,
#          'effective': 98,
#          'Congress': 98,
#          'led': 98,
#          'merely': 98,
#          'degree': 98,
#          'Island': 98,
#          'direct': 98,
#          'met': 98,
#          'instead': 98,
#          'list': 98,
#          'average': 98,
#          'gives': 98,
#          'technical': 97,
#          'aid': 97,
#          'hot': 97,
#          'forward': 97,
#          'increased': 97,
#          'boys': 97,
#          'test': 96,
#          'movement': 96,
#          'using': 96,
#          'influence': 96,
#          'fear': 96,
#          'actually': 96,
#          'returned': 96,
#          'larger': 96,
#          'character': 96,
#          'temperature': 96,
#          'manner': 95,
#          '1961': 95,
#          'former': 95,
#          'generally': 95,
#          'president': 95,
#          'University': 95,
#          'described': 95,
#          'Federal': 95,
#          'section': 95,
#          'fiscal': 95,
#          'evening': 95,
#          'stock': 95,
#          'couple': 94,
#          'Many': 94,
#          'volume': 94,
#          'understanding': 94,
#          'Secretary': 94,
#          'foreign': 94,
#          'sales': 94,
#          'chance': 94,
#          'Although': 94,
#          'decision': 94,
#          'lead': 94,
#          'hall': 94,
#          'quality': 94,
#          'earth': 94,
#          'lower': 94,
#          'due': 94,
#          'Well': 94,
#          'visit': 93,
#          'Another': 93,
#          'certainly': 93,
#          'types': 93,
#          "I'd": 93,
#          "man's": 93,
#          'function': 93,
#          'charge': 92,
#          'horse': 92,
#          'trial': 92,
#          'ways': 92,
#          'easy': 92,
#          'approach': 92,
#          'pool': 92,
#          'series': 91,
#          'immediately': 91,
#          'indicated': 91,
#          'research': 91,
#          'changes': 91,
#          'clearly': 91,
#          'nation': 91,
#          'activity': 91,
#          'answer': 91,
#          'truth': 91,
#          'wide': 91,
#          'remember': 91,
#          'main': 91,
#          'First': 91,
#          'applied': 91,
#          'attitude': 91,
#          'court': 90,
#          '30': 90,
#          'served': 90,
#          'serious': 90,
#          'freedom': 90,
#          'Negro': 90,
#          'completely': 90,
#          'efforts': 90,
#          'responsibility': 90,
#          'labor': 90,
#          'wrong': 90,
#          'lack': 90,
#          'plane': 90,
#          'corner': 90,
#          'feed': 90,
#          'shot': 89,
#          'doubt': 89,
#          'planning': 89,
#          'parts': 89,
#          'organization': 89,
#          'somewhat': 89,
#          'arms': 89,
#          'running': 89,
#          'meaning': 89,
#          'include': 89,
#          'note': 89,
#          'teeth': 89,
#          'lived': 88,
#          'bit': 88,
#          'slowly': 88,
#          'latter': 88,
#          'learned': 87,
#          'persons': 87,
#          'sun': 87,
#          'treatment': 87,
#          'beautiful': 87,
#          'recently': 87,
#          'closed': 87,
#          'farm': 87,
#          'blood': 87,
#          'principle': 87,
#          'operation': 86,
#          'afternoon': 86,
#          'cities': 86,
#          'reported': 86,
#          'works': 86,
#          'square': 86,
#          'scene': 86,
#          'account': 86,
#          'game': 86,
#          'straight': 86,
#          'ones': 86,
#          'distance': 86,
#          'easily': 86,
#          'Europe': 86,
#          'design': 86,
#          'growing': 86,
#          'numbers': 86,
#          'indeed': 86,
#          'religion': 86,
#          'audience': 85,
#          'George': 85,
#          'letters': 85,
#          'nuclear': 85,
#          'determined': 85,
#          'saying': 85,
#          'image': 85,
#          'role': 85,
#          'spring': 85,
#          'provided': 85,
#          'length': 85,
#          'appear': 85,
#          'services': 84,
#          'choice': 84,
#          'reaction': 84,
#          'mouth': 84,
#          'nearly': 84,
#          'firm': 84,
#          'entered': 84,
#          'throughout': 84,
#          'becomes': 84,
#          'cause': 84,
#          'importance': 84,
#          'Court': 83,
#          'daily': 83,
#          'moving': 83,
#          'established': 83,
#          'factors': 83,
#          'hit': 83,
#          'trees': 83,
#          'reach': 83,
#          'administration': 82,
#          'ask': 82,
#          'designed': 82,
#          'White': 82,
#          'student': 82,
#          'international': 82,
#          'specific': 82,
#          'suggested': 82,
#          'stop': 82,
#          'opportunity': 82,
#          'raised': 82,
#          'neither': 82,
#          'respect': 82,
#          'C': 82,
#          'waiting': 82,
#          'effects': 82,
#          'considerable': 82,
#          'sides': 82,
#          'stress': 82,
#          'federal': 81,
#          'spent': 81,
#          'places': 81,
#          'College': 81,
#          'Union': 81,
#          'concern': 81,
#          'central': 81,
#          'Southern': 81,
#          'officer': 81,
#          '15': 81,
#          'consider': 81,
#          'season': 81,
#          'knows': 81,
#          'stay': 81,
#          'wish': 81,
#          'shows': 81,
#          'extent': 81,
#          'write': 81,
#          'continue': 80,
#          'medical': 80,
#          'eight': 80,
#          'heavy': 80,
#          'staff': 80,
#          'covered': 80,
#          'pattern': 80,
#          'additional': 79,
#          'according': 79,
#          'attack': 79,
#          'limited': 79,
#          'figures': 79,
#          'elements': 79,
#          'hardly': 79,
#          'prepared': 79,
#          'May': 79,
#          'speak': 79,
#          'pretty': 79,
#          'accepted': 79,
#          'rise': 79,
#          'analysis': 79,
#          'gun': 78,
#          'Two': 78,
#          'highly': 78,
#          'press': 78,
#          'based': 78,
#          'events': 78,
#          'share': 78,
#          'ahead': 78,
#          'popular': 78,
#          'progress': 78,
#          'successful': 78,
#          'status': 78,
#          'faith': 78,
#          'ball': 78,
#          'weight': 78,
#          'film': 78,
#          'existence': 78,
#          'standing': 78,
#          'style': 78,
#          'quickly': 77,
#          'writing': 77,
#          'cars': 77,
#          'original': 77,
#          'caught': 77,
#          'industrial': 77,
#          'dropped': 77,
#          'Church': 77,
#          'machine': 77,
#          'built': 77,
#          'British': 77,
#          'glass': 77,
#          'demand': 76,
#          'nations': 76,
#          'income': 76,
#          'leaders': 76,
#          'radio': 76,
#          'Western': 76,
#          'deep': 76,
#          'Brown': 76,
#          'current': 76,
#          'born': 76,
#          'pieces': 76,
#          'language': 76,
#          'serve': 75,
#          'J.': 75,
#          'race': 75,
#          'plans': 75,
#          'fight': 75,
#          'require': 75,
#          'Charles': 75,
#          'energy': 75,
#          '1959': 75,
#          'explained': 75,
#          'science': 75,
#          'remained': 75,
#          '8': 75,
#          'supply': 75,
#          'filled': 75,
#          'thin': 75,
#          'expect': 75,
#          'sign': 74,
#          'apparently': 74,
#          'A.': 74,
#          'project': 74,
#          '20': 74,
#          'attempt': 74,
#          'interested': 74,
#          'techniques': 74,
#          'discussion': 74,
#          'famous': 74,
#          'included': 74,
#          'drive': 74,
#          'middle': 74,
#          'playing': 74,
#          'activities': 74,
#          'exactly': 74,
#          'inches': 74,
#          'source': 73,
#          'Rhode': 73,
#          'changed': 73,
#          'Americans': 73,
#          'active': 73,
#          'practice': 73,
#          'institutions': 73,
#          'objective': 73,
#          'married': 72,
#          'unit': 72,
#          'marked': 72,
#          'March': 72,
#          'seven': 72,
#          'green': 72,
#          'Act': 72,
#          'finished': 72,
#          'giving': 72,
#          'management': 72,
#          'ship': 72,
#          '5': 72,
#          'reasons': 72,
#          'clay': 72,
#          'pain': 72,
#          'previous': 71,
#          'determine': 71,
#          'blue': 71,
#          'parents': 71,
#          'noted': 71,
#          'philosophy': 71,
#          'Thomas': 71,
#          'S.': 71,
#          'Government': 71,
#          'loss': 71,
#          'played': 71,
#          'Jack': 71,
#          'obvious': 71,
#          'fell': 71,
#          'Perhaps': 71,
#          'marriage': 71,
#          "that's": 71,
#          'radiation': 71,
#          'standard': 71,
#          'fixed': 71,
#          'gas': 71,
#          'significant': 71,
#          'allowed': 70,
#          'none': 70,
#          'dollars': 70,
#          'poor': 70,
#          'James': 70,
#          'equal': 70,
#          'walk': 70,
#          'check': 70,
#          'appears': 70,
#          'professional': 70,
#          'thousand': 70,
#          'records': 70,
#          'products': 70,
#          'proper': 70,
#          'happy': 70,
#          ...})

# %%
window_size = 5

def random_batch(corpus, window_size=2):
    skip_grams = []

    for doc in corpus:
        for i in range(window_size, len(doc)-window_size):
            center = doc[i]

            outside_start =  i - window_size
            outside_end =  i + window_size + 1

            for j in range(outside_start, outside_end):
                if i != j:  # Skip the center word
                    outside = doc[j]
                    skip_grams.append((center, outside))

            return skip_grams
        
skip_grams = random_batch(corpus, window_size)

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('investigation', 'Fulton'): 1,
#          ('investigation', 'County'): 1,
#          ('investigation', 'Grand'): 1,
#          ('investigation', 'said'): 1,
#          ('investigation', 'Friday'): 1,
#          ('investigation', 'recent'): 1,
#          ('investigation', 'primary'): 1,
#          ('investigation', 'election'): 1,
#          ('investigation', 'produced'): 1,
#          ('investigation', '``'): 1})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
batch_size = 2
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

# %%
x
# Out:
# array([[10545],
#        [10545]])

# %%
y
# Out:
# array([[6824],
#        [7588]])

# %%
cooc
# Out:
# array([[0.],
#        [0.]])

# %%
weighting
# Out:
# array([[0.03162278],
#        [0.03162278]])

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)
    
    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %%
#test our system
voc_size = len(vocab)
emb_size = 2
model = Glove(voc_size, emb_size)

# %%
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %%
loss
# Out:
# tensor(0.0273, grad_fn=<SumBackward0>)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = Glove(voc_size, embedding_size)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
# Training
num_epochs = 1000
start = time.time()
for epoch in range(num_epochs):
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    epoch_mins, epoch_secs = epoch_time(start, time.time())

    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | Loss: {loss:.6f} | Time: {epoch_mins}m {epoch_secs}s")
# Out:
# Epoch: 100 | Loss: 0.794129 | Time: 0m 0s
# Epoch: 200 | Loss: 0.550186 | Time: 0m 0s
# Epoch: 300 | Loss: 0.380729 | Time: 0m 0s
# Epoch: 400 | Loss: 0.264631 | Time: 0m 0s
# Epoch: 500 | Loss: 0.185084 | Time: 0m 1s
# Epoch: 600 | Loss: 0.130074 | Time: 0m 1s
# Epoch: 700 | Loss: 0.091619 | Time: 0m 1s
# Epoch: 800 | Loss: 0.064508 | Time: 0m 1s
# Epoch: 900 | Loss: 0.045299 | Time: 0m 2s
# Epoch: 1000 | Loss: 0.031665 | Time: 0m 2s

# %% [markdown]
# ## 6. Plotting the embeddings

# %%
#list of vocabs
vocab[:10]
# Out:
# ['A.L.A.M.',
#  'presumably',
#  'Moon',
#  'conferences',
#  'leg',
#  'denominations',
#  'memory',
#  'assistance',
#  'two',
#  'route']

# %%
word = vocab[0]

# %%
#numericalization
id = word2index[word]
id
# Out:
# 0

# %%
id_tensor = torch.LongTensor([id])
id_tensor
# Out:
# tensor([0])

# %%
#get the embedding by averaging
v_embed = model.center_embedding(id_tensor)
u_embed = model.outside_embedding(id_tensor)

v_embed, u_embed
# Out:
# (tensor([[-0.7728,  0.2118]], grad_fn=<EmbeddingBackward0>),
#  tensor([[2.3139, 1.3517]], grad_fn=<EmbeddingBackward0>))

# %%
#average to get the word embedding
word_embed = (v_embed + u_embed) / 2
word_embed
# Out:
# tensor([[0.7705, 0.7817]], grad_fn=<DivBackward0>)

# %%
#let's write a function to get embedding given a word
def get_embed(word):
    id_tensor = torch.LongTensor([word2index[word]])
    v_embed = model.center_embedding(id_tensor)
    u_embed = model.outside_embedding(id_tensor) 
    word_embed = (v_embed + u_embed) / 2 
    x, y = word_embed[0][0].item(), word_embed[0][1].item()

    return x, y

# %% [markdown]
# ## 7. Cosine similarity
#
# Formally the [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) $s$ between two vectors $p$ and $q$ is defined as:
#
# $$s = \frac{p \cdot q}{||p|| ||q||}, \textrm{ where } s \in [-1, 1] $$
#
# If $p$ and $q$ is super similar, the result is 1 otherwise 0.

# %%
vocab
# Out:
# ['A.L.A.M.',
#  'presumably',
#  'Moon',
#  'conferences',
#  'leg',
#  'denominations',
#  'memory',
#  'assistance',
#  'two',
#  'route',
#  'sewage',
#  'calculated',
#  'revenge',
#  'Authority',
#  'four',
#  'concepts',
#  'dolls',
#  'intentions',
#  'flashes',
#  'tsunami',
#  'specimen',
#  'Federation',
#  'chin',
#  'clinging',
#  'oven',
#  'mg/l',
#  'overly',
#  'eighteen',
#  'eleven',
#  'Others',
#  'prevention',
#  'compete',
#  'passion',
#  'integrate',
#  'concerto',
#  'cousin',
#  'table',
#  'parked',
#  'supplies',
#  'Today',
#  'examining',
#  'proclamation',
#  'Wally',
#  'dressing',
#  'SBA',
#  'evaluating',
#  'references',
#  'sampled',
#  'wrinkles',
#  "Patchen's",
#  'opportunity',
#  'issued',
#  'cutting',
#  'wires',
#  'hurry',
#  'explosion',
#  'bearing',
#  'pockets',
#  'Richardson',
#  'illustrated',
#  'Gardens',
#  'recommending',
#  'dubious',
#  'forthcoming',
#  'Kirby',
#  'disease',
#  'tourists',
#  'realistically',
#  'tense',
#  'prices',
#  'screens',
#  'fostered',
#  'poetry',
#  'months',
#  'novel',
#  'aboard',
#  'present',
#  'bankers',
#  'Frankie',
#  'gravel',
#  'Andrew',
#  'forgotten',
#  'Federal',
#  'fairly',
#  'fats',
#  'adults',
#  'excitedly',
#  'Italians',
#  'inescapable',
#  'City',
#  'growing',
#  'necessity',
#  'author',
#  'arranged',
#  'grinning',
#  'Star',
#  'Miriam',
#  'consequence',
#  'promoting',
#  'equations',
#  'Legislature',
#  'wages',
#  'Menshikov',
#  'indignation',
#  'Bishop',
#  'ways',
#  'limiting',
#  'appearing',
#  'natives',
#  'X',
#  'factories',
#  'aerial',
#  'struggled',
#  'channels',
#  'instruments',
#  'brick',
#  '4',
#  "o'clock",
#  'box',
#  'Hampshire',
#  'curious',
#  'mixing',
#  'choices',
#  'pressure',
#  'engagements',
#  'Stadium',
#  'earthy',
#  'ambiguity',
#  'Eastern',
#  'accurate',
#  'wave',
#  'cottage',
#  'comfortably',
#  'Atlantic',
#  'Jimmy',
#  'recruit',
#  'heartily',
#  'coffee',
#  'relationships',
#  'absorbed',
#  'lend',
#  'grain',
#  'feed',
#  'cards',
#  'nitrogen',
#  'cargo',
#  'negotiating',
#  'carpenter',
#  'Organization',
#  'defeat',
#  'dictatorship',
#  'Ave.',
#  'theme',
#  'squeezed',
#  'nomination',
#  'proposing',
#  'detached',
#  'suggesting',
#  'Nassau',
#  'benefit',
#  'lawyer',
#  'style',
#  'Lincoln',
#  'phosphor',
#  'inference',
#  'converted',
#  'selections',
#  'rate',
#  'spinning',
#  'novels',
#  'honesty',
#  'teachers',
#  'free',
#  'Meanwhile',
#  'Still',
#  'Edward',
#  'returned',
#  'boards',
#  'ambulance',
#  'flew',
#  'learn',
#  'Also',
#  'supernatural',
#  'bond',
#  'ancestry',
#  'appreciated',
#  'center',
#  'Southerners',
#  'consists',
#  'incentive',
#  'show',
#  'flesh',
#  'trick',
#  'assign',
#  'decreased',
#  'irradiation',
#  'chairs',
#  'boost',
#  'assumes',
#  'Robert',
#  'packing',
#  'lines',
#  'orbit',
#  "State's",
#  'votes',
#  'photographic',
#  'attorney',
#  'micrometeorite',
#  'Would',
#  'expert',
#  'tactics',
#  'clergyman',
#  'limit',
#  'explicit',
#  'bronze',
#  'Hotel',
#  'glorious',
#  'scraped',
#  'relief',
#  'wore',
#  'acquainted',
#  'straightforward',
#  'Maude',
#  'faces',
#  'succession',
#  'probably',
#  'Dec.',
#  'energetic',
#  'benefits',
#  'Sons',
#  '110',
#  'prevented',
#  'doubling',
#  'ninety',
#  'sooner',
#  'shattered',
#  'replacement',
#  'divorce',
#  'external',
#  'burn',
#  'characterized',
#  'biography',
#  'Bridge',
#  'accustomed',
#  'fulfill',
#  'handicap',
#  'Swift',
#  'ripped',
#  'tender',
#  '1930',
#  'necessary',
#  'electricity',
#  'writing',
#  'passages',
#  'stirring',
#  'anecdote',
#  'irregular',
#  "Papa's",
#  'achieving',
#  'intelligible',
#  'combines',
#  'illumination',
#  'components',
#  'call',
#  'hotels',
#  'stamp',
#  'Lester',
#  'mathematics',
#  'Next',
#  'applicable',
#  'conclusion',
#  'lore',
#  'column',
#  'hear',
#  'Victor',
#  'intuition',
#  'negative',
#  'plane',
#  'brother',
#  'Wisconsin',
#  'callous',
#  'war',
#  'operand',
#  'periods',
#  'modify',
#  'initiative',
#  'shaken',
#  'picket',
#  'seen',
#  'Crombie',
#  'neglected',
#  'manners',
#  'token',
#  'lightning',
#  'compulsive',
#  'forests',
#  'findings',
#  'cylinders',
#  'Deegan',
#  'Kodyke',
#  'guarantees',
#  'Pulley',
#  'corporations',
#  'Jew',
#  'juice',
#  'narrowed',
#  'colorful',
#  'rice',
#  'exposure',
#  'birthday',
#  'vitamins',
#  'deduced',
#  'inquiries',
#  'wounded',
#  'educated',
#  'respectable',
#  'comprehensive',
#  'dropping',
#  'nature',
#  'particularly',
#  "Mann's",
#  'visitor',
#  'banks',
#  'Times',
#  'lap',
#  'killed',
#  'performing',
#  'repeating',
#  'Eden',
#  'ambassador',
#  'strewn',
#  'glanced',
#  'military',
#  'red',
#  'Nevertheless',
#  'document',
#  'Af',
#  'Lalaurie',
#  'Madden',
#  'ironic',
#  'Stone',
#  'key',
#  'disarmament',
#  'psychologists',
#  'haste',
#  'strikes',
#  'magnetism',
#  'hollow',
#  'T.',
#  'founding',
#  'bow',
#  'chromatic',
#  'Eve',
#  'revolutionary',
#  'sights',
#  'entered',
#  'taut',
#  'Sandburg',
#  'warnings',
#  'hats',
#  'presentations',
#  'contains',
#  'enemies',
#  'Anthony',
#  'relationship',
#  'continuity',
#  'generators',
#  'Englishmen',
#  'strand',
#  'pack',
#  'utilizing',
#  "poet's",
#  'transformation',
#  'tasted',
#  'arguing',
#  'Union',
#  'however',
#  'Angie',
#  'Van',
#  'vertical',
#  '1,000',
#  'thermometer',
#  'hair',
#  '0.5',
#  'characterization',
#  'couples',
#  'greatness',
#  'elimination',
#  'turned',
#  'stopped',
#  'Pohl',
#  'Boys',
#  'players',
#  'settled',
#  'contributing',
#  'approval',
#  'apparent',
#  'tells',
#  "B'dikkat",
#  'Chester',
#  'exhibited',
#  '17th',
#  'comprise',
#  'Madame',
#  'Square',
#  'essential',
#  'discrimination',
#  'whiskey',
#  'Dallas',
#  'Ada',
#  'chairmen',
#  'wishes',
#  'evaluation',
#  'received',
#  'judged',
#  'actually',
#  'campus',
#  'responded',
#  'sensitivity',
#  'House',
#  'power',
#  'seventeen',
#  'Bank',
#  'increasing',
#  'December',
#  'Expressway',
#  '24',
#  "car's",
#  'inserted',
#  'mothers',
#  'sentenced',
#  'Local',
#  'shipping',
#  'glancing',
#  'incredible',
#  'equitable',
#  'pill',
#  'notice',
#  'needs',
#  'slept',
#  'E.',
#  'frail',
#  'reasons',
#  'Katie',
#  'pointed',
#  'polarization',
#  'addressing',
#  'camps',
#  'decency',
#  'threads',
#  'strategy',
#  'footsteps',
#  'tax',
#  'conceivable',
#  'Laboratory',
#  'sanction',
#  'began',
#  'Ruth',
#  'gin',
#  'script',
#  "Pont's",
#  'True',
#  'TSH',
#  'delegation',
#  'heavier',
#  'push',
#  'builders',
#  'friction',
#  'abstract',
#  'ideal',
#  'Philip',
#  'residence',
#  'purchasing',
#  'directions',
#  'orthodox',
#  'ballistic',
#  'speed',
#  'peasants',
#  'harvest',
#  'mixed',
#  'chances',
#  'traded',
#  'drainage',
#  'Cavalry',
#  'motel',
#  'bonds',
#  'whatever',
#  'reactivity',
#  'Cubism',
#  'go',
#  'chemistry',
#  'assembly',
#  'Water',
#  'strides',
#  'ethical',
#  'highly',
#  'cyclist',
#  'GOP',
#  'maps',
#  'Ray',
#  'towels',
#  'admire',
#  'Hillsboro',
#  'entirely',
#  'Olgivanna',
#  'remembering',
#  'luck',
#  'breadth',
#  'brings',
#  'sins',
#  'repaired',
#  'selecting',
#  'forgive',
#  'solids',
#  'partition',
#  'cage',
#  'saloons',
#  'quietly',
#  'conductor',
#  'maids',
#  'wonder',
#  'Drill',
#  'retrieved',
#  'leading',
#  'bacteria',
#  'Soviet',
#  'teach',
#  'anti-Semitism',
#  'steps',
#  'flexibility',
#  'spraying',
#  'p.',
#  'widespread',
#  'locating',
#  'Newark',
#  'hay',
#  'treating',
#  'winding',
#  'constructive',
#  'Barton',
#  'mist',
#  'sharing',
#  'Achievement',
#  'wondering',
#  'stored',
#  'decision',
#  'scores',
#  'cheeks',
#  'politics',
#  'Foreign',
#  'Methodist',
#  'polyether',
#  'borrowing',
#  'whole',
#  'constants',
#  'label',
#  'whites',
#  'bees',
#  'Hesperus',
#  'goals',
#  'cancel',
#  'fails',
#  'stove',
#  'financing',
#  'seats',
#  'relevant',
#  'agriculture',
#  "Plato's",
#  'Consider',
#  'February',
#  'augmented',
#  'ceiling',
#  'knee',
#  'lighted',
#  'words',
#  'questioned',
#  'boundaries',
#  'directional',
#  'Prairie',
#  'Harrington',
#  'theft',
#  'waiting',
#  'theaters',
#  'Tom',
#  'machinery',
#  'Seminary',
#  'superstition',
#  'plowing',
#  'cure',
#  'spacious',
#  'proceeded',
#  'thirty',
#  'Partlow',
#  'diagram',
#  'recipe',
#  'reach',
#  'accomplishment',
#  'traditional',
#  'pile',
#  'Columbus',
#  'Smith',
#  'provide',
#  'lousy',
#  'Bureau',
#  'spectrum',
#  'brown',
#  'influential',
#  'barn',
#  'popular',
#  'mouths',
#  'Zen',
#  'Looking',
#  'grant',
#  'easy',
#  'vacations',
#  'hazards',
#  'damp',
#  'Maria',
#  'mayor',
#  'bullet',
#  'Trevelyan',
#  "nation's",
#  'privileges',
#  'wagon',
#  'divine',
#  'course',
#  "America's",
#  'Birds',
#  'threaten',
#  "Government's",
#  'long-range',
#  'accessories',
#  "wife's",
#  'Beatrice',
#  'allowing',
#  'Graham',
#  'Depot',
#  'M.',
#  'World',
#  'pride',
#  'used',
#  'sources',
#  'promises',
#  'intersection',
#  'Back',
#  'Anderson',
#  'sister',
#  'transmission',
#  'Commission',
#  'discharge',
#  'us',
#  'installations',
#  'impulse',
#  'reply',
#  "woman's",
#  'academy',
#  'rubbing',
#  'alien',
#  'artist',
#  'elbows',
#  'observation',
#  'adoption',
#  'arbitrary',
#  'Friends',
#  'Todman',
#  'singing',
#  'Alabama',
#  'movements',
#  'pants',
#  'Opera',
#  'driveway',
#  'penetrating',
#  'cruelty',
#  'stared',
#  'study',
#  'grasp',
#  'overt',
#  'Buzz',
#  'immediately',
#  'scholarships',
#  'express',
#  'assumed',
#  'print',
#  'believes',
#  'legal',
#  'occurring',
#  'mutually',
#  'first',
#  'successful',
#  'watercolor',
#  'gum',
#  'forms',
#  'diplomacy',
#  'functioning',
#  'save',
#  'par',
#  'represented',
#  'mystery',
#  'Mass',
#  'studies',
#  'winning',
#  'Princeton',
#  'declaring',
#  'wool',
#  'Khrushchev',
#  'Connally',
#  'vaguely',
#  'chip',
#  'substances',
#  'simply',
#  'considerations',
#  '1000',
#  'Mays',
#  'remain',
#  'Pollock',
#  'Oliver',
#  'customer',
#  'correctly',
#  'missiles',
#  'established',
#  'Kent',
#  'current',
#  'politically',
#  '30',
#  'virtually',
#  'seventh',
#  'mortgage',
#  'looked',
#  'deduction',
#  'looks',
#  'identified',
#  'flames',
#  'marched',
#  'swelling',
#  'diseases',
#  'meal',
#  'Plato',
#  'Louis',
#  'evaluate',
#  'vitality',
#  'therefore',
#  'shades',
#  'compared',
#  'Corp.',
#  'concerts',
#  'bush',
#  'interim',
#  'indications',
#  'producer',
#  'coatings',
#  'vividly',
#  'already',
#  'acquisition',
#  'wanting',
#  'cutters',
#  'planners',
#  'ignored',
#  'petition',
#  'chooses',
#  'sensational',
#  'showing',
#  'deciding',
#  'victim',
#  'privately',
#  'receiver',
#  "Hudson's",
#  'calculation',
#  'whirling',
#  'muffled',
#  'Hirey',
#  'vacant',
#  'noted',
#  'V.',
#  'millions',
#  'programing',
#  'Bridget',
#  'trotted',
#  'merchants',
#  'guiding',
#  'realtors',
#  'feels',
#  'rent',
#  'simple',
#  'missed',
#  'quicker',
#  'everyday',
#  'private',
#  'Maryland',
#  'partially',
#  'Ever',
#  'contracts',
#  'guns',
#  'sounds',
#  'reserve',
#  'heated',
#  'somewhat',
#  "let's",
#  'safe',
#  'pin',
#  'related',
#  'favorably',
#  'bills',
#  'fired',
#  'conversion',
#  'Microscopically',
#  'yelled',
#  'staining',
#  'lots',
#  'measure',
#  'Future',
#  'Social',
#  'Shore',
#  'valley',
#  'readiness',
#  'designated',
#  'assignments',
#  'drain',
#  'intensifiers',
#  'poured',
#  'Shortly',
#  'estate',
#  'reactors',
#  'bird',
#  'smiling',
#  'fabric',
#  'perfect',
#  'antibody',
#  "Kennedy's",
#  'hostility',
#  'servants',
#  'witness',
#  'Usually',
#  'Handley',
#  'foundations',
#  'unprepared',
#  'searching',
#  'collective',
#  'drag',
#  'baptized',
#  '9',
#  'mourning',
#  'cumulative',
#  'westward',
#  'hard',
#  'repeatedly',
#  'Cathy',
#  'veranda',
#  'Take',
#  'stuck',
#  'shares',
#  'porous',
#  'curiosity',
#  'announced',
#  'talking',
#  'contained',
#  'meadow',
#  'nod',
#  'shelters',
#  'Foods',
#  'instituted',
#  'incorporated',
#  'educational',
#  'surprising',
#  'calcium',
#  'affirm',
#  'buses',
#  'clover',
#  'northern',
#  'photographs',
#  'Cardinal',
#  'inspiration',
#  'Form',
#  'price',
#  'exceptional',
#  'origins',
#  'disputes',
#  '7:30',
#  'grateful',
#  'electrons',
#  'among',
#  'Porter',
#  'Guam',
#  'greeted',
#  'true',
#  'procurement',
#  'sixth',
#  'Claire',
#  'Gray',
#  'Creator',
#  'eyelids',
#  'strict',
#  'cheerful',
#  'tail',
#  'Brooklyn',
#  'provides',
#  'supportive',
#  'affairs',
#  'cries',
#  'Thayer',
#  'authority',
#  'prosecution',
#  'Roy',
#  'person',
#  'controversial',
#  'aircraft',
#  'disastrous',
#  'recommendations',
#  'Hamrick',
#  'tremendous',
#  'Benson',
#  'obviously',
#  'eastern',
#  'Kohnstamm-negative',
#  'retained',
#  'scope',
#  'conclusive',
#  'machine',
#  'resort',
#  'Bobby',
#  'financial',
#  'becomes',
#  'exercise',
#  'answered',
#  'emergencies',
#  'sixty-five',
#  'offense',
#  'canvas',
#  'advisory',
#  'recall',
#  'analogous',
#  'prone',
#  'rabbit',
#  'habits',
#  'levers',
#  'ideological',
#  'accept',
#  'like',
#  'performances',
#  'pronounced',
#  'enormous',
#  'Appendix',
#  'receipts',
#  'hiding',
#  'breast',
#  'indefinite',
#  'player',
#  'shifts',
#  'queen',
#  'wings',
#  'angles',
#  'random',
#  'standpoint',
#  'Dulles',
#  'Thanks',
#  'enforce',
#  'tube',
#  'grimly',
#  'degree',
#  'edition',
#  'partly',
#  'difference',
#  'bundles',
#  'Discovery',
#  'fighter',
#  "child's",
#  'Holmes',
#  'remove',
#  'grow',
#  'cope',
#  'monument',
#  'thyroid',
#  'worthwhile',
#  'speak',
#  'honey',
#  'Jess',
#  'arguments',
#  'within',
#  'leader',
#  'genuinely',
#  'Great',
#  'Hong',
#  'strings',
#  'signing',
#  'director',
#  'outside',
#  'unpleasant',
#  'Revenue',
#  'ceramic',
#  'born',
#  'employment',
#  'size',
#  'B',
#  'Joan',
#  'generous',
#  'besides',
#  'enables',
#  'cut',
#  'span',
#  'Cousin',
#  'soils',
#  ...]

# %%
#let's try similarity between first and second, and second and third
cat          = get_embed('cat')
fruit        = get_embed('fruit')
animal       = get_embed('animal')

# %%
def cos_sim(a, b):
    cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
    return cos_sim
    
print(f"cat vs. fruit: ",        cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))
# Out:
# cat vs. fruit:  -0.307626941728896
# cat vs. animal:  0.9857794932591222
# cat vs. cat:  1.0

# %%
def cos_sim(a, b):
    cos_sim = 1 - spatial.distance.cosine(a, b)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim

print(f"cat vs. fruit: ",        cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))
# Out:
# cat vs. fruit:  -0.30762694172889593
# cat vs. animal:  0.9857794932591222
# cat vs. cat:  1.0

# %%
# Create a pickle of the model
import pickle

with open('glove.pkl', 'wb') as f:
    pickle.dump(model, f)
